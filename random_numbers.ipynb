# %%
import random

# %%
random.random()
# Out:
# 0.6409065483141972

# %%
random.randint(-10,10)
# Out:
# 4

# %%
random_number = random.randint(-90,89) + random.random()
random_number
# Out:
# 56.98857166259512

# %%
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1
    
latitudes
# Out:
# [59.57826802820997,
#  55.196658591179194,
#  68.72938453330832,
#  -5.743950513692434,
#  74.01007318685907,
#  -59.26035291892337,
#  84.34147030277224,
#  34.86385489209127,
#  -15.264806642370747,
#  -42.6045799156916]

# %%
random.randrange(-90,90, step=1)
# Out:
# 80

# %%
random.randrange(-90,90, step=5)
# Out:
# -65

# %%
random.uniform(-90,90)
# Out:
# 55.006838579817384

# %%
import numpy as np

# %%
np.random.uniform(-90.000,90.000)
# Out:
# 50.245758075042176

# %%
np.random.uniform(-90.000,90.000, size = 50)
# Out:
# array([ -8.08325257,  29.18361236,  26.76353648, -39.77852247,
#         83.37669003,  68.98093993,  82.94540391,  25.0629352 ,
#        -46.5602748 , -72.76210025,  77.83160245,  44.1087725 ,
#         19.91333041,   9.73706772, -16.62337055, -39.93283228,
#         56.79012855, -34.83211732, -28.23406818,  60.39438477,
#        -30.91976558,  43.97641017,  35.39141847,  18.62607162,
#        -41.56055727,  67.15873592,  85.67978813, -64.9916586 ,
#         81.85646459, -69.42668989, -30.64746838,  71.23633673,
#        -28.81078995,  75.1124481 ,  16.73451128, -77.11070394,
#          0.17681687, -48.08543462, -69.44227894, -22.88681528,
#        -15.84505593,  -1.29410144, -37.04352153,  15.91004314,
#        -49.88641783, -39.52772003,  11.0957472 , -75.48831881,
#         59.39806889, -19.32467295])

# %%
import timeit

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 45.6 µs ± 2.02 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 6.29 ms ± 234 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = np.random.uniform(-90.000, 90.000, size=1500) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 115 ms ± 3.41 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
