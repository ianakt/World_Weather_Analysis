# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
import requests
import csv

from citipy import citipy
from config import weather_api_key
from datetime import datetime
from scipy.stats import linregress
import timeit

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Openweather API

# e54b389430ada7e562d27816cae2bdaa

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 772

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e54b389430ada7e562d27816cae2bdaa

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e54b389430ada7e562d27816cae2bdaa&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descr = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_descr})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
    # WHERE IS CITIES DEFINED IN MODULE!!!!???
        # Cell 3
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 1 | natal
# Processing Record 3 of Set 1 | pevek
# Processing Record 4 of Set 1 | crab hill
# City not found. Skipping...
# Processing Record 5 of Set 1 | conceicao das alagoas
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | longyearbyen
# Processing Record 8 of Set 1 | bumba
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | arraial do cabo
# Processing Record 11 of Set 1 | sadovoye
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | mehamn
# Processing Record 14 of Set 1 | beatrice
# Processing Record 15 of Set 1 | wagar
# Processing Record 16 of Set 1 | carnarvon
# Processing Record 17 of Set 1 | ribeira grande
# Processing Record 18 of Set 1 | nassau
# Processing Record 19 of Set 1 | grindavik
# Processing Record 20 of Set 1 | guasdualito
# Processing Record 21 of Set 1 | galich
# Processing Record 22 of Set 1 | calbuco
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | caernarfon
# Processing Record 25 of Set 1 | bethel
# Processing Record 26 of Set 1 | greytown
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | muros
# Processing Record 30 of Set 1 | bredasdorp
# Processing Record 31 of Set 1 | krutinka
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | wanning
# Processing Record 35 of Set 1 | richards bay
# Processing Record 36 of Set 1 | new norfolk
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | biak
# Processing Record 39 of Set 1 | ancud
# Processing Record 40 of Set 1 | saint-georges
# Processing Record 41 of Set 1 | west bay
# Processing Record 42 of Set 1 | neiafu
# Processing Record 43 of Set 1 | dundwaraganj
# Processing Record 44 of Set 1 | tuktoyaktuk
# Processing Record 45 of Set 1 | aswan
# Processing Record 46 of Set 1 | lorengau
# Processing Record 47 of Set 1 | barrow
# Processing Record 48 of Set 1 | nabire
# Processing Record 49 of Set 1 | chokurdakh
# Processing Record 50 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 2 | leon
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | puerto ayora
# Processing Record 4 of Set 2 | lulea
# Processing Record 5 of Set 2 | te anau
# Processing Record 6 of Set 2 | east london
# Processing Record 7 of Set 2 | namibe
# Processing Record 8 of Set 2 | avarua
# Processing Record 9 of Set 2 | gorom-gorom
# Processing Record 10 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 2 | victoria
# Processing Record 12 of Set 2 | geraldton
# Processing Record 13 of Set 2 | khatanga
# Processing Record 14 of Set 2 | pisco
# Processing Record 15 of Set 2 | pimentel
# Processing Record 16 of Set 2 | aykhal
# Processing Record 17 of Set 2 | kruisfontein
# Processing Record 18 of Set 2 | tilichiki
# Processing Record 19 of Set 2 | yellowknife
# Processing Record 20 of Set 2 | hermanus
# Processing Record 21 of Set 2 | katsuura
# Processing Record 22 of Set 2 | kismayo
# Processing Record 23 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 24 of Set 2 | ushuaia
# Processing Record 25 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 26 of Set 2 | ceres
# Processing Record 27 of Set 2 | lata
# Processing Record 28 of Set 2 | contamana
# Processing Record 29 of Set 2 | aklavik
# Processing Record 30 of Set 2 | montbeliard
# Processing Record 31 of Set 2 | chengde
# Processing Record 32 of Set 2 | ust-ishim
# Processing Record 33 of Set 2 | hasaki
# Processing Record 34 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 2 | phitsanulok
# Processing Record 36 of Set 2 | santa cruz
# Processing Record 37 of Set 2 | shelopugino
# Processing Record 38 of Set 2 | hare bay
# Processing Record 39 of Set 2 | sao francisco
# Processing Record 40 of Set 2 | ust-kuyga
# Processing Record 41 of Set 2 | lavrentiya
# Processing Record 42 of Set 2 | kavaratti
# Processing Record 43 of Set 2 | clyde river
# Processing Record 44 of Set 2 | progreso
# Processing Record 45 of Set 2 | alugan
# Processing Record 46 of Set 2 | burgeo
# Processing Record 47 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 2 | traralgon
# Processing Record 49 of Set 2 | half moon bay
# Processing Record 50 of Set 2 | tiksi
# Processing Record 1 of Set 3 | bongued
# Processing Record 2 of Set 3 | punta arenas
# Processing Record 3 of Set 3 | graham
# Processing Record 4 of Set 3 | ojinaga
# Processing Record 5 of Set 3 | miri
# Processing Record 6 of Set 3 | seoul
# Processing Record 7 of Set 3 | pemangkat
# Processing Record 8 of Set 3 | kavieng
# Processing Record 9 of Set 3 | atambua
# Processing Record 10 of Set 3 | kosonsoy
# Processing Record 11 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 3 | camacha
# Processing Record 13 of Set 3 | ponta do sol
# Processing Record 14 of Set 3 | kapaa
# Processing Record 15 of Set 3 | ostrovnoy
# Processing Record 16 of Set 3 | norman wells
# Processing Record 17 of Set 3 | victor harbor
# Processing Record 18 of Set 3 | ouricuri
# Processing Record 19 of Set 3 | saldanha
# Processing Record 20 of Set 3 | toftir
# City not found. Skipping...
# Processing Record 21 of Set 3 | haapiti
# Processing Record 22 of Set 3 | marondera
# Processing Record 23 of Set 3 | dikson
# Processing Record 24 of Set 3 | saskylakh
# Processing Record 25 of Set 3 | key west
# Processing Record 26 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 3 | alpena
# Processing Record 28 of Set 3 | flin flon
# Processing Record 29 of Set 3 | georgetown
# Processing Record 30 of Set 3 | pombas
# Processing Record 31 of Set 3 | yulara
# Processing Record 32 of Set 3 | pa sang
# Processing Record 33 of Set 3 | zhigansk
# Processing Record 34 of Set 3 | shashi
# Processing Record 35 of Set 3 | cape town
# Processing Record 36 of Set 3 | talnakh
# Processing Record 37 of Set 3 | mount gambier
# Processing Record 38 of Set 3 | saint-philippe
# Processing Record 39 of Set 3 | slave lake
# Processing Record 40 of Set 3 | acapulco
# Processing Record 41 of Set 3 | duvan
# Processing Record 42 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 43 of Set 3 | villa carlos paz
# Processing Record 44 of Set 3 | port alfred
# Processing Record 45 of Set 3 | tasiilaq
# Processing Record 46 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 3 | lebu
# Processing Record 48 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 3 | bamako
# Processing Record 50 of Set 3 | deputatskiy
# Processing Record 1 of Set 4 | kuryk
# Processing Record 2 of Set 4 | chuy
# Processing Record 3 of Set 4 | torbay
# Processing Record 4 of Set 4 | darhan
# Processing Record 5 of Set 4 | saint-augustin
# Processing Record 6 of Set 4 | esperance
# Processing Record 7 of Set 4 | jalu
# Processing Record 8 of Set 4 | kodiak
# Processing Record 9 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 10 of Set 4 | guerrero negro
# Processing Record 11 of Set 4 | mlonggo
# Processing Record 12 of Set 4 | bintulu
# Processing Record 13 of Set 4 | maymyo
# Processing Record 14 of Set 4 | vostok
# Processing Record 15 of Set 4 | asau
# Processing Record 16 of Set 4 | sola
# Processing Record 17 of Set 4 | puertollano
# Processing Record 18 of Set 4 | zhangjiakou
# Processing Record 19 of Set 4 | hokitika
# Processing Record 20 of Set 4 | noumea
# Processing Record 21 of Set 4 | nuuk
# Processing Record 22 of Set 4 | mattru
# Processing Record 23 of Set 4 | lyuban
# Processing Record 24 of Set 4 | butaritari
# Processing Record 25 of Set 4 | caravelas
# Processing Record 26 of Set 4 | ylojarvi
# Processing Record 27 of Set 4 | akyab
# Processing Record 28 of Set 4 | tyumentsevo
# Processing Record 29 of Set 4 | andapa
# Processing Record 30 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 31 of Set 4 | port elizabeth
# Processing Record 32 of Set 4 | kizilskoye
# Processing Record 33 of Set 4 | port lincoln
# Processing Record 34 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 4 | burns lake
# Processing Record 36 of Set 4 | ossora
# Processing Record 37 of Set 4 | langangen
# City not found. Skipping...
# Processing Record 38 of Set 4 | monrovia
# Processing Record 39 of Set 4 | chaman
# Processing Record 40 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 4 | hualmay
# Processing Record 42 of Set 4 | kyra
# Processing Record 43 of Set 4 | mgandu
# Processing Record 44 of Set 4 | xai-xai
# Processing Record 45 of Set 4 | vestmannaeyjar
# Processing Record 46 of Set 4 | faya
# Processing Record 47 of Set 4 | singaraja
# Processing Record 48 of Set 4 | upernavik
# Processing Record 49 of Set 4 | geresk
# City not found. Skipping...
# Processing Record 50 of Set 4 | toowoomba
# Processing Record 1 of Set 5 | bathsheba
# Processing Record 2 of Set 5 | palana
# Processing Record 3 of Set 5 | grand-lahou
# Processing Record 4 of Set 5 | port moresby
# Processing Record 5 of Set 5 | boguchany
# Processing Record 6 of Set 5 | sedelnikovo
# City not found. Skipping...
# Processing Record 7 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 8 of Set 5 | fortuna
# Processing Record 9 of Set 5 | gat
# Processing Record 10 of Set 5 | bluff
# Processing Record 11 of Set 5 | kagadi
# Processing Record 12 of Set 5 | bambous virieux
# Processing Record 13 of Set 5 | ambon
# Processing Record 14 of Set 5 | bandarbeyla
# Processing Record 15 of Set 5 | dunedin
# Processing Record 16 of Set 5 | bauchi
# Processing Record 17 of Set 5 | gazimagusa
# City not found. Skipping...
# Processing Record 18 of Set 5 | madaoua
# Processing Record 19 of Set 5 | minab
# Processing Record 20 of Set 5 | damaturu
# Processing Record 21 of Set 5 | sorland
# Processing Record 22 of Set 5 | cidreira
# Processing Record 23 of Set 5 | greer
# Processing Record 24 of Set 5 | neuquen
# Processing Record 25 of Set 5 | pangody
# Processing Record 26 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 5 | nome
# Processing Record 28 of Set 5 | santa fe
# Processing Record 29 of Set 5 | moose factory
# Processing Record 30 of Set 5 | cedar city
# Processing Record 31 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 32 of Set 5 | muroto
# Processing Record 33 of Set 5 | broken hill
# Processing Record 34 of Set 5 | anadyr
# Processing Record 35 of Set 5 | kaitangata
# Processing Record 36 of Set 5 | wamba
# Processing Record 37 of Set 5 | virginia beach
# Processing Record 38 of Set 5 | faanui
# Processing Record 39 of Set 5 | great bend
# Processing Record 40 of Set 5 | garissa
# Processing Record 41 of Set 5 | port blair
# Processing Record 42 of Set 5 | fairbanks
# Processing Record 43 of Set 5 | waipawa
# Processing Record 44 of Set 5 | ust-tsilma
# Processing Record 45 of Set 5 | pitkyaranta
# Processing Record 46 of Set 5 | riviera beach
# Processing Record 47 of Set 5 | urumqi
# Processing Record 48 of Set 5 | sri aman
# Processing Record 49 of Set 5 | misratah
# Processing Record 50 of Set 5 | vytegra
# Processing Record 1 of Set 6 | zhuhai
# Processing Record 2 of Set 6 | santiago del estero
# Processing Record 3 of Set 6 | narsaq
# Processing Record 4 of Set 6 | jiwani
# Processing Record 5 of Set 6 | mujiayingzi
# Processing Record 6 of Set 6 | ceuta
# Processing Record 7 of Set 6 | pierre
# Processing Record 8 of Set 6 | lincoln
# Processing Record 9 of Set 6 | luau
# Processing Record 10 of Set 6 | alofi
# Processing Record 11 of Set 6 | porbandar
# Processing Record 12 of Set 6 | boddam
# Processing Record 13 of Set 6 | dingle
# Processing Record 14 of Set 6 | bagan
# Processing Record 15 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 16 of Set 6 | meulaboh
# Processing Record 17 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 18 of Set 6 | castro
# Processing Record 19 of Set 6 | isangel
# Processing Record 20 of Set 6 | sechura
# Processing Record 21 of Set 6 | albion
# Processing Record 22 of Set 6 | boa vista
# Processing Record 23 of Set 6 | ulladulla
# Processing Record 24 of Set 6 | nahrin
# Processing Record 25 of Set 6 | padang
# Processing Record 26 of Set 6 | aksu
# Processing Record 27 of Set 6 | inirida
# Processing Record 28 of Set 6 | vestbygda
# City not found. Skipping...
# Processing Record 29 of Set 6 | vila franca do campo
# Processing Record 30 of Set 6 | berlevag
# Processing Record 31 of Set 6 | zyryanka
# Processing Record 32 of Set 6 | severo-kurilsk
# Processing Record 33 of Set 6 | seoni malwa
# Processing Record 34 of Set 6 | cozumel
# Processing Record 35 of Set 6 | hovd
# Processing Record 36 of Set 6 | sakakah
# Processing Record 37 of Set 6 | san andres
# Processing Record 38 of Set 6 | vanimo
# Processing Record 39 of Set 6 | keti bandar
# Processing Record 40 of Set 6 | manakara
# Processing Record 41 of Set 6 | klaksvik
# Processing Record 42 of Set 6 | sinnamary
# Processing Record 43 of Set 6 | iranshahr
# Processing Record 44 of Set 6 | la ronge
# Processing Record 45 of Set 6 | sobolevo
# Processing Record 46 of Set 6 | tolaga bay
# Processing Record 47 of Set 6 | baruun-urt
# Processing Record 48 of Set 6 | mayor pablo lagerenza
# Processing Record 49 of Set 6 | lugovoy
# Processing Record 50 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 7 | sisimiut
# Processing Record 2 of Set 7 | lithakia
# Processing Record 3 of Set 7 | khandyga
# Processing Record 4 of Set 7 | coquimbo
# Processing Record 5 of Set 7 | poli
# Processing Record 6 of Set 7 | lagoa
# Processing Record 7 of Set 7 | korhogo
# Processing Record 8 of Set 7 | verkhoyansk
# Processing Record 9 of Set 7 | turukhansk
# Processing Record 10 of Set 7 | santa rosa
# Processing Record 11 of Set 7 | divnomorskoye
# Processing Record 12 of Set 7 | ormara
# Processing Record 13 of Set 7 | luanda
# Processing Record 14 of Set 7 | coolum beach
# Processing Record 15 of Set 7 | natalio
# Processing Record 16 of Set 7 | nikolskoye
# Processing Record 17 of Set 7 | constitucion
# Processing Record 18 of Set 7 | klyuchi
# Processing Record 19 of Set 7 | nanortalik
# Processing Record 20 of Set 7 | lima
# Processing Record 21 of Set 7 | mahebourg
# Processing Record 22 of Set 7 | milkovo
# Processing Record 23 of Set 7 | yatou
# Processing Record 24 of Set 7 | naze
# Processing Record 25 of Set 7 | manaure
# Processing Record 26 of Set 7 | san patricio
# Processing Record 27 of Set 7 | iqaluit
# Processing Record 28 of Set 7 | nikolayevsk-na-amure
# Processing Record 29 of Set 7 | nadym
# Processing Record 30 of Set 7 | dalnerechensk
# Processing Record 31 of Set 7 | nyuksenitsa
# Processing Record 32 of Set 7 | sfantu gheorghe
# Processing Record 33 of Set 7 | palafrugell
# Processing Record 34 of Set 7 | bilibino
# Processing Record 35 of Set 7 | beringovskiy
# Processing Record 36 of Set 7 | kaeo
# Processing Record 37 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 38 of Set 7 | thinadhoo
# Processing Record 39 of Set 7 | mersing
# Processing Record 40 of Set 7 | qaanaaq
# Processing Record 41 of Set 7 | quatre cocos
# Processing Record 42 of Set 7 | cabo san lucas
# Processing Record 43 of Set 7 | trairi
# Processing Record 44 of Set 7 | kailua
# Processing Record 45 of Set 7 | de aar
# Processing Record 46 of Set 7 | otsuchi
# Processing Record 47 of Set 7 | matara
# Processing Record 48 of Set 7 | mushie
# Processing Record 49 of Set 7 | nhulunbuy
# Processing Record 50 of Set 7 | okhotsk
# Processing Record 1 of Set 8 | havelock
# Processing Record 2 of Set 8 | paamiut
# Processing Record 3 of Set 8 | vila velha
# Processing Record 4 of Set 8 | provideniya
# Processing Record 5 of Set 8 | pacific grove
# Processing Record 6 of Set 8 | andevoranto
# City not found. Skipping...
# Processing Record 7 of Set 8 | lovozero
# Processing Record 8 of Set 8 | hirara
# Processing Record 9 of Set 8 | sumbe
# Processing Record 10 of Set 8 | galgani
# City not found. Skipping...
# Processing Record 11 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 8 | tumaco
# Processing Record 13 of Set 8 | kungalv
# Processing Record 14 of Set 8 | harper
# Processing Record 15 of Set 8 | cherskiy
# Processing Record 16 of Set 8 | olinda
# Processing Record 17 of Set 8 | hofn
# Processing Record 18 of Set 8 | arlit
# Processing Record 19 of Set 8 | nieves
# Processing Record 20 of Set 8 | eureka
# Processing Record 21 of Set 8 | omboue
# Processing Record 22 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 23 of Set 8 | urubicha
# Processing Record 24 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 8 | bhongir
# Processing Record 26 of Set 8 | lodwar
# Processing Record 27 of Set 8 | krasnaya gora
# Processing Record 28 of Set 8 | balkhash
# Processing Record 29 of Set 8 | ponta delgada
# Processing Record 30 of Set 8 | agua dulce
# Processing Record 31 of Set 8 | byron bay
# Processing Record 32 of Set 8 | augusto correa
# Processing Record 33 of Set 8 | orange cove
# Processing Record 34 of Set 8 | itarema
# Processing Record 35 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 36 of Set 8 | cumpas
# Processing Record 37 of Set 8 | hithadhoo
# Processing Record 38 of Set 8 | blackwater
# Processing Record 39 of Set 8 | gwadar
# Processing Record 40 of Set 8 | imeni poliny osipenko
# Processing Record 41 of Set 8 | pentecoste
# Processing Record 42 of Set 8 | stornoway
# Processing Record 43 of Set 8 | ola
# Processing Record 44 of Set 8 | rocha
# Processing Record 45 of Set 8 | taoudenni
# Processing Record 46 of Set 8 | yerbogachen
# Processing Record 47 of Set 8 | kieta
# Processing Record 48 of Set 8 | budhlada
# Processing Record 49 of Set 8 | katobu
# Processing Record 50 of Set 8 | sangar
# Processing Record 1 of Set 9 | marovoay
# Processing Record 2 of Set 9 | bengkulu
# Processing Record 3 of Set 9 | cam pha
# City not found. Skipping...
# Processing Record 4 of Set 9 | belmonte
# Processing Record 5 of Set 9 | atar
# Processing Record 6 of Set 9 | jacareacanga
# Processing Record 7 of Set 9 | mount isa
# Processing Record 8 of Set 9 | hailar
# Processing Record 9 of Set 9 | westport
# Processing Record 10 of Set 9 | san quintin
# Processing Record 11 of Set 9 | kaura namoda
# Processing Record 12 of Set 9 | lixourion
# Processing Record 13 of Set 9 | kuandian
# Processing Record 14 of Set 9 | nizhnyaya tura
# Processing Record 15 of Set 9 | carutapera
# Processing Record 16 of Set 9 | roma
# Processing Record 17 of Set 9 | milingimbi
# City not found. Skipping...
# Processing Record 18 of Set 9 | jiuquan
# Processing Record 19 of Set 9 | pangnirtung
# Processing Record 20 of Set 9 | muzhi
# Processing Record 21 of Set 9 | tura
# Processing Record 22 of Set 9 | bull savanna
# Processing Record 23 of Set 9 | ayer itam
# City not found. Skipping...
# Processing Record 24 of Set 9 | campos
# Processing Record 25 of Set 9 | kurilsk
# Processing Record 26 of Set 9 | turtkul
# City not found. Skipping...
# Processing Record 27 of Set 9 | santa marta
# Processing Record 28 of Set 9 | zhangye
# Processing Record 29 of Set 9 | sitka
# Processing Record 30 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 9 | meambar
# City not found. Skipping...
# Processing Record 32 of Set 9 | mar del plata
# Processing Record 33 of Set 9 | berdigestyakh
# Processing Record 34 of Set 9 | bloomington
# Processing Record 35 of Set 9 | udachnyy
# Processing Record 36 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 9 | baiyin
# Processing Record 38 of Set 9 | qurayyat
# Processing Record 39 of Set 9 | vardo
# Processing Record 40 of Set 9 | comodoro rivadavia
# Processing Record 41 of Set 9 | batemans bay
# Processing Record 42 of Set 9 | cabrera
# Processing Record 43 of Set 9 | wanaka
# Processing Record 44 of Set 9 | grand gaube
# Processing Record 45 of Set 9 | vestmanna
# Processing Record 46 of Set 9 | kirksville
# Processing Record 47 of Set 9 | kuna
# Processing Record 48 of Set 9 | olafsvik
# Processing Record 49 of Set 9 | souillac
# Processing Record 50 of Set 9 | pathardi
# Processing Record 1 of Set 10 | lemesos
# City not found. Skipping...
# Processing Record 2 of Set 10 | medea
# Processing Record 3 of Set 10 | port hedland
# Processing Record 4 of Set 10 | brae
# Processing Record 5 of Set 10 | barra do garcas
# Processing Record 6 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 10 | hay river
# Processing Record 8 of Set 10 | xichang
# Processing Record 9 of Set 10 | los llanos de aridane
# Processing Record 10 of Set 10 | samarai
# Processing Record 11 of Set 10 | tautira
# Processing Record 12 of Set 10 | chitral
# Processing Record 13 of Set 10 | rayadrug
# Processing Record 14 of Set 10 | turayf
# Processing Record 15 of Set 10 | waikuku
# Processing Record 16 of Set 10 | edd
# Processing Record 17 of Set 10 | sherbakul
# Processing Record 18 of Set 10 | bartica
# Processing Record 19 of Set 10 | luderitz
# Processing Record 20 of Set 10 | taltal
# Processing Record 21 of Set 10 | aseri
# Processing Record 22 of Set 10 | shimoda
# Processing Record 23 of Set 10 | cascais
# Processing Record 24 of Set 10 | yuancheng
# Processing Record 25 of Set 10 | poum
# Processing Record 26 of Set 10 | gondanglegi
# Processing Record 27 of Set 10 | maputo
# Processing Record 28 of Set 10 | galiwinku
# City not found. Skipping...
# Processing Record 29 of Set 10 | ambovombe
# Processing Record 30 of Set 10 | callaway
# Processing Record 31 of Set 10 | port keats
# Processing Record 32 of Set 10 | ilulissat
# Processing Record 33 of Set 10 | guamuchil
# Processing Record 34 of Set 10 | conceicao da barra
# Processing Record 35 of Set 10 | george
# Processing Record 36 of Set 10 | bermeo
# Processing Record 37 of Set 10 | chake chake
# Processing Record 38 of Set 10 | pilao arcado
# City not found. Skipping...
# Processing Record 39 of Set 10 | chara
# Processing Record 40 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 10 | onega
# Processing Record 42 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 43 of Set 10 | saint george
# Processing Record 44 of Set 10 | yamethin
# Processing Record 45 of Set 10 | emborion
# Processing Record 46 of Set 10 | jinchang
# Processing Record 47 of Set 10 | salekhard
# Processing Record 48 of Set 10 | adrar
# Processing Record 49 of Set 10 | salym
# Processing Record 50 of Set 10 | abu kamal
# Processing Record 1 of Set 11 | santa isabel
# Processing Record 2 of Set 11 | eyl
# Processing Record 3 of Set 11 | hire
# City not found. Skipping...
# Processing Record 4 of Set 11 | viedma
# Processing Record 5 of Set 11 | jawhar
# Processing Record 6 of Set 11 | vallenar
# Processing Record 7 of Set 11 | opuwo
# Processing Record 8 of Set 11 | nouadhibou
# Processing Record 9 of Set 11 | ortona
# Processing Record 10 of Set 11 | springbok
# Processing Record 11 of Set 11 | manicore
# Processing Record 12 of Set 11 | lillooet
# Processing Record 13 of Set 11 | whyalla
# Processing Record 14 of Set 11 | entre rios
# Processing Record 15 of Set 11 | trapani
# Processing Record 16 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 11 | gao
# Processing Record 18 of Set 11 | broome
# Processing Record 19 of Set 11 | ahlat
# Processing Record 20 of Set 11 | marawi
# Processing Record 21 of Set 11 | kishapu
# Processing Record 22 of Set 11 | telhara
# Processing Record 23 of Set 11 | porto novo
# Processing Record 24 of Set 11 | rock hill
# Processing Record 25 of Set 11 | suntar
# Processing Record 26 of Set 11 | ouargaye
# Processing Record 27 of Set 11 | sumy
# Processing Record 28 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 29 of Set 11 | sharan
# Processing Record 30 of Set 11 | ulaangom
# Processing Record 31 of Set 11 | farafangana
# Processing Record 32 of Set 11 | wodonga
# Processing Record 33 of Set 11 | ambunti
# Processing Record 34 of Set 11 | la rioja
# Processing Record 35 of Set 11 | hammonton
# Processing Record 36 of Set 11 | abha
# Processing Record 37 of Set 11 | moerai
# Processing Record 38 of Set 11 | nantucket
# Processing Record 39 of Set 11 | airai
# Processing Record 40 of Set 11 | san cristobal
# Processing Record 41 of Set 11 | yeppoon
# Processing Record 42 of Set 11 | anderson
# Processing Record 43 of Set 11 | cowra
# Processing Record 44 of Set 11 | oktyabrskoye
# Processing Record 45 of Set 11 | pangkalanbuun
# Processing Record 46 of Set 11 | solnechnyy
# Processing Record 47 of Set 11 | kibungo
# Processing Record 48 of Set 11 | husavik
# Processing Record 49 of Set 11 | simao
# Processing Record 50 of Set 11 | lucknow
# Processing Record 1 of Set 12 | arona
# Processing Record 2 of Set 12 | laguna
# Processing Record 3 of Set 12 | goderich
# Processing Record 4 of Set 12 | yar-sale
# Processing Record 5 of Set 12 | skibbereen
# Processing Record 6 of Set 12 | panguna
# Processing Record 7 of Set 12 | reforma
# Processing Record 8 of Set 12 | kaseda
# Processing Record 9 of Set 12 | acarau
# Processing Record 10 of Set 12 | kahului
# Processing Record 11 of Set 12 | hamilton
# Processing Record 12 of Set 12 | bitung
# Processing Record 13 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 12 | dubbo
# Processing Record 15 of Set 12 | geilo
# Processing Record 16 of Set 12 | yarmouth
# Processing Record 17 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 18 of Set 12 | nyrob
# Processing Record 19 of Set 12 | otane
# Processing Record 20 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 22 of Set 12 | hervey bay
# Processing Record 23 of Set 12 | carnduff
# Processing Record 24 of Set 12 | leeton
# Processing Record 25 of Set 12 | aasiaat
# Processing Record 26 of Set 12 | rogova
# Processing Record 27 of Set 12 | prince albert
# Processing Record 28 of Set 12 | isla vista
# Processing Record 29 of Set 12 | tokur
# Processing Record 30 of Set 12 | todos santos
# Processing Record 31 of Set 12 | mahanoro
# Processing Record 32 of Set 12 | pyshchug
# Processing Record 33 of Set 12 | baykit
# Processing Record 34 of Set 12 | san policarpo
# Processing Record 35 of Set 12 | nago
# Processing Record 36 of Set 12 | necochea
# Processing Record 37 of Set 12 | naryan-mar
# Processing Record 38 of Set 12 | rio gallegos
# Processing Record 39 of Set 12 | saint-jean-de-maurienne
# Processing Record 40 of Set 12 | qaqortoq
# Processing Record 41 of Set 12 | luis correia
# Processing Record 42 of Set 12 | tonekabon
# Processing Record 43 of Set 12 | palmer
# Processing Record 44 of Set 12 | conakry
# Processing Record 45 of Set 12 | impfondo
# Processing Record 46 of Set 12 | chornobay
# Processing Record 47 of Set 12 | bhuban
# Processing Record 48 of Set 12 | bocaranga
# City not found. Skipping...
# Processing Record 49 of Set 12 | sao felix do xingu
# Processing Record 50 of Set 12 | ahipara
# Processing Record 1 of Set 13 | george town
# Processing Record 2 of Set 13 | kendrapara
# Processing Record 3 of Set 13 | waitati
# Processing Record 4 of Set 13 | sao filipe
# Processing Record 5 of Set 13 | damietta
# Processing Record 6 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 7 of Set 13 | doha
# Processing Record 8 of Set 13 | karakol
# Processing Record 9 of Set 13 | saint pete beach
# Processing Record 10 of Set 13 | vero beach
# Processing Record 11 of Set 13 | pauini
# Processing Record 12 of Set 13 | kargasok
# Processing Record 13 of Set 13 | roald
# Processing Record 14 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 15 of Set 13 | kramat
# Processing Record 16 of Set 13 | moyale
# Processing Record 17 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 18 of Set 13 | palm coast
# Processing Record 19 of Set 13 | rawson
# Processing Record 20 of Set 13 | cotonou
# Processing Record 21 of Set 13 | rio grande
# Processing Record 22 of Set 13 | villanueva
# Processing Record 23 of Set 13 | zyryanovsk
# Processing Record 24 of Set 13 | jacqueville
# Processing Record 25 of Set 13 | portland
# Processing Record 26 of Set 13 | aykino
# Processing Record 27 of Set 13 | mayskiy
# Processing Record 28 of Set 13 | banda aceh
# Processing Record 29 of Set 13 | maniitsoq
# Processing Record 30 of Set 13 | lompoc
# Processing Record 31 of Set 13 | sorong
# Processing Record 32 of Set 13 | waingapu
# Processing Record 33 of Set 13 | walvis bay
# Processing Record 34 of Set 13 | verkhnyachka
# Processing Record 35 of Set 13 | dicabisagan
# Processing Record 36 of Set 13 | chico
# Processing Record 37 of Set 13 | pedernales
# Processing Record 38 of Set 13 | umm lajj
# Processing Record 39 of Set 13 | antofagasta
# Processing Record 40 of Set 13 | mangan
# Processing Record 41 of Set 13 | abnub
# Processing Record 42 of Set 13 | bikaner
# Processing Record 43 of Set 13 | the valley
# Processing Record 44 of Set 13 | great malvern
# Processing Record 45 of Set 13 | codrington
# Processing Record 46 of Set 13 | jaisalmer
# Processing Record 47 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 48 of Set 13 | yumen
# Processing Record 49 of Set 13 | harrismith
# Processing Record 50 of Set 13 | port hardy
# Processing Record 1 of Set 14 | djambala
# Processing Record 2 of Set 14 | ituiutaba
# Processing Record 3 of Set 14 | salalah
# Processing Record 4 of Set 14 | lasa
# Processing Record 5 of Set 14 | assiniboia
# Processing Record 6 of Set 14 | leningradskiy
# Processing Record 7 of Set 14 | sept-iles
# Processing Record 8 of Set 14 | dwarka
# Processing Record 9 of Set 14 | suleya
# Processing Record 10 of Set 14 | karratha
# Processing Record 11 of Set 14 | phalombe
# Processing Record 12 of Set 14 | waynesville
# Processing Record 13 of Set 14 | casa nova
# Processing Record 14 of Set 14 | cabo rojo
# Processing Record 15 of Set 14 | jishou
# Processing Record 16 of Set 14 | fort madison
# Processing Record 17 of Set 14 | anamur
# Processing Record 18 of Set 14 | krasnoselkup
# Processing Record 19 of Set 14 | christchurch
# Processing Record 20 of Set 14 | pavagada
# Processing Record 21 of Set 14 | zhuanghe
# Processing Record 22 of Set 14 | lakatoro
# Processing Record 23 of Set 14 | acajutla
# Processing Record 24 of Set 14 | ca mau
# Processing Record 25 of Set 14 | praxedis guerrero
# Processing Record 26 of Set 14 | gamba
# Processing Record 27 of Set 14 | buala
# Processing Record 28 of Set 14 | sabha
# Processing Record 29 of Set 14 | dzaoudzi
# Processing Record 30 of Set 14 | kudahuvadhoo
# Processing Record 31 of Set 14 | parkersburg
# Processing Record 32 of Set 14 | bantry
# Processing Record 33 of Set 14 | tomohon
# Processing Record 34 of Set 14 | chapais
# Processing Record 35 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 36 of Set 14 | finnsnes
# Processing Record 37 of Set 14 | hazorasp
# Processing Record 38 of Set 14 | nurota
# Processing Record 39 of Set 14 | multan
# Processing Record 40 of Set 14 | sambava
# Processing Record 41 of Set 14 | tuatapere
# Processing Record 42 of Set 14 | lushunkou
# City not found. Skipping...
# Processing Record 43 of Set 14 | cardenas
# Processing Record 44 of Set 14 | crateus
# Processing Record 45 of Set 14 | brigantine
# Processing Record 46 of Set 14 | rae bareli
# Processing Record 47 of Set 14 | belyy yar
# Processing Record 48 of Set 14 | hays
# Processing Record 49 of Set 14 | kem
# Processing Record 50 of Set 14 | saint anthony
# Processing Record 1 of Set 15 | inhambane
# Processing Record 2 of Set 15 | yebaishou
# Processing Record 3 of Set 15 | rock springs
# Processing Record 4 of Set 15 | santa catalina
# Processing Record 5 of Set 15 | golub-dobrzyn
# Processing Record 6 of Set 15 | springfield
# Processing Record 7 of Set 15 | talara
# Processing Record 8 of Set 15 | bondoukou
# Processing Record 9 of Set 15 | port arthur
# Processing Record 10 of Set 15 | bay roberts
# Processing Record 11 of Set 15 | bud
# Processing Record 12 of Set 15 | kununurra
# Processing Record 13 of Set 15 | kambam
# Processing Record 14 of Set 15 | high rock
# Processing Record 15 of Set 15 | plettenberg bay
# Processing Record 16 of Set 15 | dutse
# Processing Record 17 of Set 15 | sioux lookout
# Processing Record 18 of Set 15 | altea
# Processing Record 19 of Set 15 | oussouye
# Processing Record 20 of Set 15 | flinders
# Processing Record 21 of Set 15 | tessalit
# Processing Record 22 of Set 15 | vila
# Processing Record 23 of Set 15 | nicoya
# Processing Record 24 of Set 15 | latung
# Processing Record 25 of Set 15 | tomatlan
# Processing Record 26 of Set 15 | sardinata
# Processing Record 27 of Set 15 | tanabe
# Processing Record 28 of Set 15 | fundao
# Processing Record 29 of Set 15 | kenora
# Processing Record 30 of Set 15 | tabou
# Processing Record 31 of Set 15 | alfonsine
# Processing Record 32 of Set 15 | manavgat
# Processing Record 33 of Set 15 | masinigudi
# Processing Record 34 of Set 15 | galle
# Processing Record 35 of Set 15 | sao jose da coroa grande
# Processing Record 36 of Set 15 | rurrenabaque
# Processing Record 37 of Set 15 | najran
# Processing Record 38 of Set 15 | neubrandenburg
# Processing Record 39 of Set 15 | cartagena
# Processing Record 40 of Set 15 | digha
# Processing Record 41 of Set 15 | paka
# Processing Record 42 of Set 15 | torres
# Processing Record 43 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 44 of Set 15 | luba
# Processing Record 45 of Set 15 | black diamond
# Processing Record 46 of Set 15 | bontang
# Processing Record 47 of Set 15 | kassala
# Processing Record 48 of Set 15 | mabama
# Processing Record 49 of Set 15 | bagdarin
# Processing Record 50 of Set 15 | matane
# Processing Record 1 of Set 16 | shumskiy
# Processing Record 2 of Set 16 | kamenka
# Processing Record 3 of Set 16 | college
# Processing Record 4 of Set 16 | dawlatabad
# Processing Record 5 of Set 16 | kochevo
# Processing Record 6 of Set 16 | takoradi
# Processing Record 7 of Set 16 | ziro
# Processing Record 8 of Set 16 | hami
# Processing Record 9 of Set 16 | kindu
# Processing Record 10 of Set 16 | bacuit
# City not found. Skipping...
# Processing Record 11 of Set 16 | haines junction
# Processing Record 12 of Set 16 | madison heights
# Processing Record 13 of Set 16 | dzhebariki-khaya
# Processing Record 14 of Set 16 | batetskiy
# Processing Record 15 of Set 16 | letlhakane
# Processing Record 16 of Set 16 | berga
# Processing Record 17 of Set 16 | coihaique
# Processing Record 18 of Set 16 | stokmarknes
# Processing Record 19 of Set 16 | limbazi
# Processing Record 20 of Set 16 | kaduna
# Processing Record 21 of Set 16 | nision
# Processing Record 22 of Set 16 | la cruz
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                  Natal  -5.7950  -35.2094     79.45        83          40
# 1                  Pevek  69.7008  170.3133    -34.11       100          77
# 2  Conceicao Das Alagoas -19.9147  -48.3883     69.15        94          93
# 3                Mataura -46.1927  168.8643     50.63        97         100
# 4           Longyearbyen  78.2186   15.6401     15.64        57          40
# 5                  Bumba   2.1833   22.4667     72.39        48         100
# 6                Rikitea -23.1203 -134.9692     78.28        76         100
# 7        Arraial Do Cabo -22.9661  -42.0278     75.72        90           0
# 8               Sadovoye  47.7764   44.5089     19.90        99          83
# 9                   Hilo  19.7297 -155.0900     77.25        81           9
#
#    Wind Speed Country Current Description
# 0        3.44      BR    scattered clouds
# 1        3.58      RU       broken clouds
# 2        3.83      BR     overcast clouds
# 3        3.58      NZ     overcast clouds
# 4       19.57      SJ    scattered clouds
# 5        1.57      CD     overcast clouds
# 6       15.88      PF          light rain
# 7       17.85      BR           clear sky
# 8        7.94      RU       broken clouds
# 9        1.01      US           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
