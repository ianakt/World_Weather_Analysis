# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
import requests
import csv

from citipy import citipy
from config import weather_api_key
from datetime import datetime
from scipy.stats import linregress
import timeit

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Openweather API

# e54b389430ada7e562d27816cae2bdaa

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 782

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e54b389430ada7e562d27816cae2bdaa"
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e54b389430ada7e562d27816cae2bdaa

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e54b389430ada7e562d27816cae2bdaa&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descr = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_descr,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
    # WHERE IS CITIES DEFINED IN MODULE!!!!???
        # Cell 3
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | gat
# Processing Record 3 of Set 1 | yuli
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | ruwi
# Processing Record 6 of Set 1 | neuquen
# Processing Record 7 of Set 1 | zarnovica
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | carnarvon
# Processing Record 10 of Set 1 | wadi musa
# Processing Record 11 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 1 | axim
# Processing Record 14 of Set 1 | mitsamiouli
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | saskylakh
# Processing Record 17 of Set 1 | tuktoyaktuk
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | comodoro rivadavia
# Processing Record 20 of Set 1 | mount gambier
# Processing Record 21 of Set 1 | new norfolk
# Processing Record 22 of Set 1 | ippy
# Processing Record 23 of Set 1 | hobart
# Processing Record 24 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 1 | iqaluit
# Processing Record 26 of Set 1 | ugoofaaru
# Processing Record 27 of Set 1 | athabasca
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | freeport
# Processing Record 31 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 1 | zhezkazgan
# Processing Record 35 of Set 1 | caucaia
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | murgab
# Processing Record 39 of Set 1 | leningradskiy
# Processing Record 40 of Set 1 | shwebo
# Processing Record 41 of Set 1 | yellowknife
# Processing Record 42 of Set 1 | chuy
# Processing Record 43 of Set 1 | bambous virieux
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | fortuna
# Processing Record 46 of Set 1 | thompson
# Processing Record 47 of Set 1 | pevek
# Processing Record 48 of Set 1 | kupang
# Processing Record 49 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 50 of Set 1 | prince rupert
# Processing Record 1 of Set 2 | college
# Processing Record 2 of Set 2 | port alfred
# Processing Record 3 of Set 2 | east london
# Processing Record 4 of Set 2 | rawson
# Processing Record 5 of Set 2 | provideniya
# Processing Record 6 of Set 2 | hithadhoo
# Processing Record 7 of Set 2 | road town
# Processing Record 8 of Set 2 | avarua
# Processing Record 9 of Set 2 | moose factory
# Processing Record 10 of Set 2 | longyearbyen
# Processing Record 11 of Set 2 | florianopolis
# Processing Record 12 of Set 2 | kargil
# Processing Record 13 of Set 2 | grindavik
# Processing Record 14 of Set 2 | cidreira
# Processing Record 15 of Set 2 | wahran
# City not found. Skipping...
# Processing Record 16 of Set 2 | burica
# City not found. Skipping...
# Processing Record 17 of Set 2 | jimma
# Processing Record 18 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 2 | cap malheureux
# Processing Record 20 of Set 2 | qaanaaq
# Processing Record 21 of Set 2 | tanshui
# City not found. Skipping...
# Processing Record 22 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 2 | urucara
# Processing Record 24 of Set 2 | santander
# Processing Record 25 of Set 2 | oranjestad
# Processing Record 26 of Set 2 | mwingi
# Processing Record 27 of Set 2 | bredasdorp
# Processing Record 28 of Set 2 | kaitangata
# Processing Record 29 of Set 2 | bengbu
# Processing Record 30 of Set 2 | albany
# Processing Record 31 of Set 2 | kyshtovka
# Processing Record 32 of Set 2 | griffith
# Processing Record 33 of Set 2 | anamur
# Processing Record 34 of Set 2 | zhanatas
# City not found. Skipping...
# Processing Record 35 of Set 2 | khatanga
# Processing Record 36 of Set 2 | lebu
# Processing Record 37 of Set 2 | coihueco
# Processing Record 38 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 2 | rikitea
# Processing Record 40 of Set 2 | luderitz
# Processing Record 41 of Set 2 | maun
# Processing Record 42 of Set 2 | lompoc
# Processing Record 43 of Set 2 | saint george
# Processing Record 44 of Set 2 | dingle
# Processing Record 45 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 2 | ponta do sol
# Processing Record 47 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 2 | bethel
# Processing Record 49 of Set 2 | tigzirt
# Processing Record 50 of Set 2 | merauke
# Processing Record 1 of Set 3 | dakar
# Processing Record 2 of Set 3 | tiksi
# Processing Record 3 of Set 3 | santa marta
# Processing Record 4 of Set 3 | beisfjord
# Processing Record 5 of Set 3 | sao felix do xingu
# Processing Record 6 of Set 3 | tshela
# Processing Record 7 of Set 3 | port elizabeth
# Processing Record 8 of Set 3 | puerto ayora
# Processing Record 9 of Set 3 | nikolskoye
# Processing Record 10 of Set 3 | sopetran
# Processing Record 11 of Set 3 | agadir
# Processing Record 12 of Set 3 | puerto maldonado
# Processing Record 13 of Set 3 | ribeira grande
# Processing Record 14 of Set 3 | tasiilaq
# Processing Record 15 of Set 3 | cabo san lucas
# Processing Record 16 of Set 3 | hobyo
# Processing Record 17 of Set 3 | abu samrah
# Processing Record 18 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 3 | aswan
# Processing Record 20 of Set 3 | upernavik
# Processing Record 21 of Set 3 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 22 of Set 3 | torbay
# Processing Record 23 of Set 3 | batsfjord
# Processing Record 24 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 3 | sola
# Processing Record 26 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 3 | yanji
# Processing Record 28 of Set 3 | sampit
# Processing Record 29 of Set 3 | albi
# Processing Record 30 of Set 3 | port macquarie
# Processing Record 31 of Set 3 | russkaya polyana
# Processing Record 32 of Set 3 | cherskiy
# Processing Record 33 of Set 3 | launceston
# Processing Record 34 of Set 3 | phalombe
# Processing Record 35 of Set 3 | atar
# Processing Record 36 of Set 3 | bandarban
# Processing Record 37 of Set 3 | egvekinot
# Processing Record 38 of Set 3 | butaritari
# Processing Record 39 of Set 3 | dikson
# Processing Record 40 of Set 3 | souillac
# Processing Record 41 of Set 3 | mandan
# Processing Record 42 of Set 3 | sitka
# Processing Record 43 of Set 3 | airai
# Processing Record 44 of Set 3 | djambala
# Processing Record 45 of Set 3 | clausthal-zellerfeld
# Processing Record 46 of Set 3 | mahanoro
# Processing Record 47 of Set 3 | bengkulu
# Processing Record 48 of Set 3 | havoysund
# Processing Record 49 of Set 3 | georgetown
# Processing Record 50 of Set 3 | sao filipe
# Processing Record 1 of Set 4 | huaicheng
# Processing Record 2 of Set 4 | norman wells
# Processing Record 3 of Set 4 | phan thiet
# Processing Record 4 of Set 4 | ariquemes
# Processing Record 5 of Set 4 | batemans bay
# Processing Record 6 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 7 of Set 4 | kapaa
# Processing Record 8 of Set 4 | castro
# Processing Record 9 of Set 4 | geraldton
# Processing Record 10 of Set 4 | grand gaube
# Processing Record 11 of Set 4 | stolin
# Processing Record 12 of Set 4 | sao joao da barra
# Processing Record 13 of Set 4 | menongue
# Processing Record 14 of Set 4 | tazmalt
# Processing Record 15 of Set 4 | cayenne
# Processing Record 16 of Set 4 | tianpeng
# Processing Record 17 of Set 4 | klaksvik
# Processing Record 18 of Set 4 | hermanus
# Processing Record 19 of Set 4 | te anau
# Processing Record 20 of Set 4 | nioro
# Processing Record 21 of Set 4 | ferme-neuve
# Processing Record 22 of Set 4 | zolotinka
# City not found. Skipping...
# Processing Record 23 of Set 4 | stokmarknes
# Processing Record 24 of Set 4 | polunochnoye
# Processing Record 25 of Set 4 | tupik
# Processing Record 26 of Set 4 | rawlins
# Processing Record 27 of Set 4 | chokurdakh
# Processing Record 28 of Set 4 | rey bouba
# Processing Record 29 of Set 4 | kedrovyy
# Processing Record 30 of Set 4 | kamaishi
# Processing Record 31 of Set 4 | lima
# Processing Record 32 of Set 4 | broken hill
# Processing Record 33 of Set 4 | lagos
# Processing Record 34 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 35 of Set 4 | katsuura
# Processing Record 36 of Set 4 | chase
# Processing Record 37 of Set 4 | chara
# Processing Record 38 of Set 4 | ambon
# Processing Record 39 of Set 4 | rio grande
# Processing Record 40 of Set 4 | mount isa
# Processing Record 41 of Set 4 | kazanka
# Processing Record 42 of Set 4 | mahebourg
# Processing Record 43 of Set 4 | znamenka
# Processing Record 44 of Set 4 | sept-iles
# Processing Record 45 of Set 4 | half moon bay
# Processing Record 46 of Set 4 | teul
# City not found. Skipping...
# Processing Record 47 of Set 4 | nhulunbuy
# Processing Record 48 of Set 4 | yomitan
# City not found. Skipping...
# Processing Record 49 of Set 4 | columbus
# Processing Record 50 of Set 4 | kavaratti
# Processing Record 1 of Set 5 | tshikapa
# Processing Record 2 of Set 5 | san isidro
# Processing Record 3 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 5 | ilebo
# Processing Record 5 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 5 | bathsheba
# Processing Record 7 of Set 5 | dingzhou
# Processing Record 8 of Set 5 | ebebiyin
# Processing Record 9 of Set 5 | santa maria del tule
# Processing Record 10 of Set 5 | pak phanang
# Processing Record 11 of Set 5 | sabha
# Processing Record 12 of Set 5 | nuoro
# Processing Record 13 of Set 5 | atuona
# Processing Record 14 of Set 5 | abha
# Processing Record 15 of Set 5 | gizo
# Processing Record 16 of Set 5 | baruun-urt
# Processing Record 17 of Set 5 | shaoguan
# Processing Record 18 of Set 5 | tuatapere
# Processing Record 19 of Set 5 | mar del plata
# Processing Record 20 of Set 5 | lar gerd
# City not found. Skipping...
# Processing Record 21 of Set 5 | roald
# Processing Record 22 of Set 5 | flin flon
# Processing Record 23 of Set 5 | kommunisticheskiy
# Processing Record 24 of Set 5 | pangody
# Processing Record 25 of Set 5 | hami
# Processing Record 26 of Set 5 | saldanha
# Processing Record 27 of Set 5 | kavieng
# Processing Record 28 of Set 5 | simbahan
# Processing Record 29 of Set 5 | necochea
# Processing Record 30 of Set 5 | najran
# Processing Record 31 of Set 5 | japura
# Processing Record 32 of Set 5 | hofn
# Processing Record 33 of Set 5 | whyalla
# Processing Record 34 of Set 5 | jiaohe
# Processing Record 35 of Set 5 | adrar
# Processing Record 36 of Set 5 | zyryanovsk
# Processing Record 37 of Set 5 | tura
# Processing Record 38 of Set 5 | narasannapeta
# Processing Record 39 of Set 5 | curaca
# Processing Record 40 of Set 5 | olafsvik
# Processing Record 41 of Set 5 | berdigestyakh
# Processing Record 42 of Set 5 | maine-soroa
# Processing Record 43 of Set 5 | ilulissat
# Processing Record 44 of Set 5 | aksu
# Processing Record 45 of Set 5 | pisco
# Processing Record 46 of Set 5 | huilong
# Processing Record 47 of Set 5 | port moresby
# Processing Record 48 of Set 5 | sigli
# Processing Record 49 of Set 5 | severo-kurilsk
# Processing Record 50 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 6 | mutum
# Processing Record 2 of Set 6 | arys
# Processing Record 3 of Set 6 | nanortalik
# Processing Record 4 of Set 6 | bukama
# Processing Record 5 of Set 6 | naze
# Processing Record 6 of Set 6 | saint-philippe
# Processing Record 7 of Set 6 | santo tomas
# Processing Record 8 of Set 6 | vuktyl
# Processing Record 9 of Set 6 | guerrero negro
# Processing Record 10 of Set 6 | kasongo-lunda
# Processing Record 11 of Set 6 | kimparana
# Processing Record 12 of Set 6 | ampanihy
# Processing Record 13 of Set 6 | fereydun kenar
# Processing Record 14 of Set 6 | denpasar
# Processing Record 15 of Set 6 | esperance
# Processing Record 16 of Set 6 | hannibal
# Processing Record 17 of Set 6 | luza
# Processing Record 18 of Set 6 | itaituba
# Processing Record 19 of Set 6 | teguldet
# Processing Record 20 of Set 6 | yarmouth
# Processing Record 21 of Set 6 | hasaki
# Processing Record 22 of Set 6 | austin
# Processing Record 23 of Set 6 | betioky
# Processing Record 24 of Set 6 | odweyne
# Processing Record 25 of Set 6 | saint-pierre
# Processing Record 26 of Set 6 | krasnoarmeysk
# Processing Record 27 of Set 6 | raisio
# Processing Record 28 of Set 6 | channel-port aux basques
# Processing Record 29 of Set 6 | saint anthony
# Processing Record 30 of Set 6 | novikovo
# Processing Record 31 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 6 | alegrete
# Processing Record 33 of Set 6 | sao gabriel da cachoeira
# Processing Record 34 of Set 6 | zyryanka
# Processing Record 35 of Set 6 | kailua
# Processing Record 36 of Set 6 | sabang
# Processing Record 37 of Set 6 | pangnirtung
# Processing Record 38 of Set 6 | baft
# Processing Record 39 of Set 6 | lahij
# Processing Record 40 of Set 6 | isabela
# Processing Record 41 of Set 6 | hambantota
# Processing Record 42 of Set 6 | bumba
# Processing Record 43 of Set 6 | kodiak
# Processing Record 44 of Set 6 | bandarbeyla
# Processing Record 45 of Set 6 | san quintin
# Processing Record 46 of Set 6 | vanimo
# Processing Record 47 of Set 6 | merrill
# Processing Record 48 of Set 6 | kismayo
# Processing Record 49 of Set 6 | gigmoto
# Processing Record 50 of Set 6 | vad
# Processing Record 1 of Set 7 | vardo
# Processing Record 2 of Set 7 | nabire
# Processing Record 3 of Set 7 | itoman
# Processing Record 4 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 5 of Set 7 | oktyabrskoye
# Processing Record 6 of Set 7 | urumqi
# Processing Record 7 of Set 7 | lashio
# Processing Record 8 of Set 7 | udachnyy
# Processing Record 9 of Set 7 | mouzakion
# City not found. Skipping...
# Processing Record 10 of Set 7 | tateyama
# Processing Record 11 of Set 7 | lagoa
# Processing Record 12 of Set 7 | bambanglipuro
# Processing Record 13 of Set 7 | dicabisagan
# Processing Record 14 of Set 7 | yanam
# Processing Record 15 of Set 7 | richards bay
# Processing Record 16 of Set 7 | avera
# Processing Record 17 of Set 7 | luganville
# Processing Record 18 of Set 7 | garoua
# Processing Record 19 of Set 7 | dera ismail khan
# Processing Record 20 of Set 7 | neyshabur
# Processing Record 21 of Set 7 | lorengau
# Processing Record 22 of Set 7 | porec
# Processing Record 23 of Set 7 | kutum
# Processing Record 24 of Set 7 | gladstone
# Processing Record 25 of Set 7 | port hardy
# Processing Record 26 of Set 7 | san cristobal
# Processing Record 27 of Set 7 | lavumisa
# Processing Record 28 of Set 7 | ulladulla
# Processing Record 29 of Set 7 | crateus
# Processing Record 30 of Set 7 | lamu
# Processing Record 31 of Set 7 | okhotsk
# Processing Record 32 of Set 7 | suwalki
# Processing Record 33 of Set 7 | glendive
# Processing Record 34 of Set 7 | hovd
# Processing Record 35 of Set 7 | coihaique
# Processing Record 36 of Set 7 | poum
# Processing Record 37 of Set 7 | linxia
# Processing Record 38 of Set 7 | yarega
# Processing Record 39 of Set 7 | krasnyy chikoy
# Processing Record 40 of Set 7 | prado
# Processing Record 41 of Set 7 | lopandino
# Processing Record 42 of Set 7 | dunedin
# Processing Record 43 of Set 7 | cocentaina
# Processing Record 44 of Set 7 | luanda
# Processing Record 45 of Set 7 | westport
# Processing Record 46 of Set 7 | duxbury
# Processing Record 47 of Set 7 | manicore
# Processing Record 48 of Set 7 | steinbach
# Processing Record 49 of Set 7 | cottonwood
# Processing Record 50 of Set 7 | abyek
# Processing Record 1 of Set 8 | tefe
# Processing Record 2 of Set 8 | soyo
# Processing Record 3 of Set 8 | komsomolskiy
# Processing Record 4 of Set 8 | morro bay
# Processing Record 5 of Set 8 | clyde river
# Processing Record 6 of Set 8 | aden
# Processing Record 7 of Set 8 | ancud
# Processing Record 8 of Set 8 | ilo
# Processing Record 9 of Set 8 | menomonie
# Processing Record 10 of Set 8 | sioux lookout
# Processing Record 11 of Set 8 | namibe
# Processing Record 12 of Set 8 | jos
# Processing Record 13 of Set 8 | haines junction
# Processing Record 14 of Set 8 | znamenskoye
# Processing Record 15 of Set 8 | juba
# Processing Record 16 of Set 8 | floro
# Processing Record 17 of Set 8 | colquechaca
# Processing Record 18 of Set 8 | fairburn
# Processing Record 19 of Set 8 | mildura
# Processing Record 20 of Set 8 | goderich
# Processing Record 21 of Set 8 | nome
# Processing Record 22 of Set 8 | chino valley
# Processing Record 23 of Set 8 | barra patuca
# Processing Record 24 of Set 8 | kushima
# Processing Record 25 of Set 8 | yatou
# Processing Record 26 of Set 8 | hongjiang
# Processing Record 27 of Set 8 | ballina
# Processing Record 28 of Set 8 | tilichiki
# Processing Record 29 of Set 8 | jesup
# Processing Record 30 of Set 8 | vostok
# Processing Record 31 of Set 8 | korfez
# Processing Record 32 of Set 8 | lerwick
# Processing Record 33 of Set 8 | zemio
# Processing Record 34 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 8 | lazaro cardenas
# Processing Record 36 of Set 8 | solsvik
# City not found. Skipping...
# Processing Record 37 of Set 8 | navsari
# Processing Record 38 of Set 8 | lasa
# Processing Record 39 of Set 8 | ponta delgada
# Processing Record 40 of Set 8 | kruisfontein
# Processing Record 41 of Set 8 | igarka
# Processing Record 42 of Set 8 | narsaq
# Processing Record 43 of Set 8 | boende
# Processing Record 44 of Set 8 | ostrovnoy
# Processing Record 45 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 8 | akyab
# Processing Record 47 of Set 8 | alta floresta
# Processing Record 48 of Set 8 | chokwe
# Processing Record 49 of Set 8 | mahon
# Processing Record 50 of Set 8 | kawana waters
# City not found. Skipping...
# Processing Record 1 of Set 9 | rognan
# Processing Record 2 of Set 9 | pak chong
# Processing Record 3 of Set 9 | coquimbo
# Processing Record 4 of Set 9 | north bend
# Processing Record 5 of Set 9 | chake chake
# Processing Record 6 of Set 9 | inhambane
# Processing Record 7 of Set 9 | timra
# Processing Record 8 of Set 9 | boddam
# Processing Record 9 of Set 9 | chengde
# Processing Record 10 of Set 9 | jiaxing
# Processing Record 11 of Set 9 | antalaha
# Processing Record 12 of Set 9 | balikpapan
# Processing Record 13 of Set 9 | willmar
# Processing Record 14 of Set 9 | maceio
# Processing Record 15 of Set 9 | yei
# Processing Record 16 of Set 9 | svetlogorsk
# Processing Record 17 of Set 9 | kulhudhuffushi
# Processing Record 18 of Set 9 | ushtobe
# Processing Record 19 of Set 9 | ambanja
# Processing Record 20 of Set 9 | san jeronimo
# Processing Record 21 of Set 9 | chernyshevskiy
# Processing Record 22 of Set 9 | turukhansk
# Processing Record 23 of Set 9 | srednekolymsk
# Processing Record 24 of Set 9 | qiongshan
# Processing Record 25 of Set 9 | cozumel
# Processing Record 26 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 27 of Set 9 | sohag
# Processing Record 28 of Set 9 | gumdag
# Processing Record 29 of Set 9 | sompeta
# Processing Record 30 of Set 9 | oranjemund
# Processing Record 31 of Set 9 | januaria
# Processing Record 32 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 33 of Set 9 | nova olimpia
# Processing Record 34 of Set 9 | aklavik
# Processing Record 35 of Set 9 | maragogi
# Processing Record 36 of Set 9 | lamar
# Processing Record 37 of Set 9 | dumas
# Processing Record 38 of Set 9 | laguna
# Processing Record 39 of Set 9 | santa fe
# Processing Record 40 of Set 9 | omboue
# Processing Record 41 of Set 9 | imeni poliny osipenko
# Processing Record 42 of Set 9 | buala
# Processing Record 43 of Set 9 | makakilo city
# Processing Record 44 of Set 9 | san patricio
# Processing Record 45 of Set 9 | coahuayana
# Processing Record 46 of Set 9 | teya
# Processing Record 47 of Set 9 | angoche
# Processing Record 48 of Set 9 | horsham
# Processing Record 49 of Set 9 | zeya
# Processing Record 50 of Set 9 | kitimat
# Processing Record 1 of Set 10 | monrovia
# Processing Record 2 of Set 10 | shelburne
# Processing Record 3 of Set 10 | lusambo
# Processing Record 4 of Set 10 | bossangoa
# Processing Record 5 of Set 10 | la asuncion
# Processing Record 6 of Set 10 | vaitape
# Processing Record 7 of Set 10 | smidovich
# Processing Record 8 of Set 10 | baglung
# Processing Record 9 of Set 10 | sawtell
# Processing Record 10 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 10 | hualmay
# Processing Record 12 of Set 10 | sorland
# Processing Record 13 of Set 10 | brooks
# Processing Record 14 of Set 10 | feijo
# Processing Record 15 of Set 10 | marsa matruh
# Processing Record 16 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 17 of Set 10 | ahipara
# Processing Record 18 of Set 10 | shimoda
# Processing Record 19 of Set 10 | arman
# Processing Record 20 of Set 10 | mikhaylovka
# Processing Record 21 of Set 10 | kerteh
# City not found. Skipping...
# Processing Record 22 of Set 10 | puga
# Processing Record 23 of Set 10 | nicoya
# Processing Record 24 of Set 10 | ketchikan
# Processing Record 25 of Set 10 | yelniki
# Processing Record 26 of Set 10 | union
# Processing Record 27 of Set 10 | tautira
# Processing Record 28 of Set 10 | isla vista
# Processing Record 29 of Set 10 | portland
# Processing Record 30 of Set 10 | verkhnyaya toyma
# Processing Record 31 of Set 10 | sovetskiy
# Processing Record 32 of Set 10 | san mateo del mar
# Processing Record 33 of Set 10 | kirovgrad
# Processing Record 34 of Set 10 | isangel
# Processing Record 35 of Set 10 | mehamn
# Processing Record 36 of Set 10 | kirakira
# Processing Record 37 of Set 10 | abashiri
# Processing Record 38 of Set 10 | kaeo
# Processing Record 39 of Set 10 | zhanakorgan
# Processing Record 40 of Set 10 | maniitsoq
# Processing Record 41 of Set 10 | fort-shevchenko
# Processing Record 42 of Set 10 | liverpool
# Processing Record 43 of Set 10 | lavrentiya
# Processing Record 44 of Set 10 | vestmannaeyjar
# Processing Record 45 of Set 10 | acapulco
# Processing Record 46 of Set 10 | kokkola
# Processing Record 47 of Set 10 | saint-augustin
# Processing Record 48 of Set 10 | villa guerrero
# Processing Record 49 of Set 10 | awbari
# Processing Record 50 of Set 10 | tsiroanomandidy
# Processing Record 1 of Set 11 | anadyr
# Processing Record 2 of Set 11 | clarence town
# Processing Record 3 of Set 11 | plettenberg bay
# Processing Record 4 of Set 11 | jalu
# Processing Record 5 of Set 11 | misratah
# Processing Record 6 of Set 11 | khipro
# Processing Record 7 of Set 11 | agua dulce
# Processing Record 8 of Set 11 | rio gallegos
# Processing Record 9 of Set 11 | banda aceh
# Processing Record 10 of Set 11 | oistins
# Processing Record 11 of Set 11 | excelsior springs
# Processing Record 12 of Set 11 | north platte
# Processing Record 13 of Set 11 | aktau
# Processing Record 14 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 11 | pandan
# Processing Record 16 of Set 11 | voyvozh
# Processing Record 17 of Set 11 | obluche
# City not found. Skipping...
# Processing Record 18 of Set 11 | nelson bay
# Processing Record 19 of Set 11 | powell
# Processing Record 20 of Set 11 | juneau
# Processing Record 21 of Set 11 | carutapera
# Processing Record 22 of Set 11 | yelizovo
# Processing Record 23 of Set 11 | yugo-kamskiy
# Processing Record 24 of Set 11 | grand-santi
# Processing Record 25 of Set 11 | douglas
# Processing Record 26 of Set 11 | skjervoy
# Processing Record 27 of Set 11 | high level
# Processing Record 28 of Set 11 | gulfport
# Processing Record 29 of Set 11 | sungaipenuh
# Processing Record 30 of Set 11 | atambua
# Processing Record 31 of Set 11 | businga
# Processing Record 32 of Set 11 | dharan
# Processing Record 33 of Set 11 | bonavista
# Processing Record 34 of Set 11 | da nang
# Processing Record 35 of Set 11 | emba
# Processing Record 36 of Set 11 | batagay
# Processing Record 37 of Set 11 | sorong
# Processing Record 38 of Set 11 | victoria
# Processing Record 39 of Set 11 | rundu
# Processing Record 40 of Set 11 | impfondo
# Processing Record 41 of Set 11 | buenaventura
# Processing Record 42 of Set 11 | marienburg
# Processing Record 43 of Set 11 | alem paraiba
# Processing Record 44 of Set 11 | talnakh
# Processing Record 45 of Set 11 | marystown
# Processing Record 46 of Set 11 | savannah bight
# Processing Record 47 of Set 11 | kawalu
# Processing Record 48 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 49 of Set 11 | gornopravdinsk
# Processing Record 50 of Set 11 | bonfim
# Processing Record 1 of Set 12 | sisimiut
# Processing Record 2 of Set 12 | ozinki
# Processing Record 3 of Set 12 | novobirilyussy
# Processing Record 4 of Set 12 | meulaboh
# Processing Record 5 of Set 12 | bluefields
# Processing Record 6 of Set 12 | yaan
# Processing Record 7 of Set 12 | biltine
# Processing Record 8 of Set 12 | gumla
# Processing Record 9 of Set 12 | touros
# Processing Record 10 of Set 12 | majene
# Processing Record 11 of Set 12 | husavik
# Processing Record 12 of Set 12 | aras
# Processing Record 13 of Set 12 | ituni
# City not found. Skipping...
# Processing Record 14 of Set 12 | luba
# Processing Record 15 of Set 12 | oum hadjer
# Processing Record 16 of Set 12 | homer
# Processing Record 17 of Set 12 | fairbanks
# Processing Record 18 of Set 12 | ustupo
# Processing Record 19 of Set 12 | ovalle
# Processing Record 20 of Set 12 | navahrudak
# Processing Record 21 of Set 12 | gannan
# Processing Record 22 of Set 12 | abdanan
# Processing Record 23 of Set 12 | leh
# Processing Record 24 of Set 12 | masvingo
# Processing Record 25 of Set 12 | gurupi
# Processing Record 26 of Set 12 | akdepe
# Processing Record 27 of Set 12 | mirnyy
# Processing Record 28 of Set 12 | paysandu
# Processing Record 29 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 30 of Set 12 | marang
# Processing Record 31 of Set 12 | mount vernon
# Processing Record 32 of Set 12 | bekhtery
# Processing Record 33 of Set 12 | tadine
# Processing Record 34 of Set 12 | seguela
# Processing Record 35 of Set 12 | los llanos de aridane
# Processing Record 36 of Set 12 | virtsu
# Processing Record 37 of Set 12 | ulaanbaatar
# Processing Record 38 of Set 12 | ixtapa
# Processing Record 39 of Set 12 | mongui
# Processing Record 40 of Set 12 | salta
# Processing Record 41 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 12 | kahului
# Processing Record 43 of Set 12 | beringovskiy
# Processing Record 44 of Set 12 | esna
# Processing Record 45 of Set 12 | sambava
# Processing Record 46 of Set 12 | dongsheng
# Processing Record 47 of Set 12 | deputatskiy
# Processing Record 48 of Set 12 | fort nelson
# Processing Record 49 of Set 12 | lahaina
# Processing Record 50 of Set 12 | klaeng
# Processing Record 1 of Set 13 | micheweni
# Processing Record 2 of Set 13 | alexandria
# Processing Record 3 of Set 13 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 4 of Set 13 | auki
# Processing Record 5 of Set 13 | constitucion
# Processing Record 6 of Set 13 | altar
# Processing Record 7 of Set 13 | pyatnitskoye
# Processing Record 8 of Set 13 | srivardhan
# Processing Record 9 of Set 13 | tonj
# Processing Record 10 of Set 13 | krasnovishersk
# Processing Record 11 of Set 13 | lokoja
# Processing Record 12 of Set 13 | foumban
# Processing Record 13 of Set 13 | inskoy
# Processing Record 14 of Set 13 | codrington
# Processing Record 15 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 16 of Set 13 | dhidhdhoo
# Processing Record 17 of Set 13 | soligalich
# Processing Record 18 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 19 of Set 13 | port hawkesbury
# Processing Record 20 of Set 13 | didsbury
# Processing Record 21 of Set 13 | qui nhon
# Processing Record 22 of Set 13 | sao miguel do araguaia
# Processing Record 23 of Set 13 | general roca
# Processing Record 24 of Set 13 | tonekabon
# Processing Record 25 of Set 13 | jonesboro
# Processing Record 26 of Set 13 | los andes
# Processing Record 27 of Set 13 | bull savanna
# Processing Record 28 of Set 13 | marsh harbour
# Processing Record 29 of Set 13 | fomboni
# Processing Record 30 of Set 13 | humaita
# Processing Record 31 of Set 13 | votkinsk
# Processing Record 32 of Set 13 | luau
# Processing Record 33 of Set 13 | bealanana
# Processing Record 34 of Set 13 | wenchi
# Processing Record 35 of Set 13 | samarai
# Processing Record 36 of Set 13 | cairns
# Processing Record 37 of Set 13 | porlamar
# Processing Record 38 of Set 13 | zhuhai
# Processing Record 39 of Set 13 | nemuro
# Processing Record 40 of Set 13 | puerto quijarro
# Processing Record 41 of Set 13 | biu
# Processing Record 42 of Set 13 | vila velha
# Processing Record 43 of Set 13 | ceres
# Processing Record 44 of Set 13 | hauterive
# Processing Record 45 of Set 13 | xapuri
# Processing Record 46 of Set 13 | saint-paul
# Processing Record 47 of Set 13 | salcedo
# Processing Record 48 of Set 13 | rosita
# Processing Record 49 of Set 13 | conchas
# Processing Record 50 of Set 13 | san francisco
# Processing Record 1 of Set 14 | rizhao
# Processing Record 2 of Set 14 | flinders
# Processing Record 3 of Set 14 | port-de-bouc
# Processing Record 4 of Set 14 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 14 | karratha
# Processing Record 6 of Set 14 | ocos
# Processing Record 7 of Set 14 | cotacachi
# Processing Record 8 of Set 14 | asau
# Processing Record 9 of Set 14 | wajima
# Processing Record 10 of Set 14 | dobryatino
# Processing Record 11 of Set 14 | taoudenni
# Processing Record 12 of Set 14 | qunduz
# Processing Record 13 of Set 14 | san carlos de bariloche
# Processing Record 14 of Set 14 | russell
# Processing Record 15 of Set 14 | gamba
# Processing Record 16 of Set 14 | pimenta bueno
# Processing Record 17 of Set 14 | burnie
# Processing Record 18 of Set 14 | langtad
# Processing Record 19 of Set 14 | marfino
# Processing Record 20 of Set 14 | sao jose da coroa grande
# Processing Record 21 of Set 14 | achacachi
# Processing Record 22 of Set 14 | korla
# Processing Record 23 of Set 14 | zhuanghe
# Processing Record 24 of Set 14 | kichera
# Processing Record 25 of Set 14 | whitehorse
# Processing Record 26 of Set 14 | victor harbor
# Processing Record 27 of Set 14 | kurtamysh
# Processing Record 28 of Set 14 | eyl
# Processing Record 29 of Set 14 | schoningen
# Processing Record 30 of Set 14 | saint-francois
# Processing Record 31 of Set 14 | kenai
# Processing Record 32 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 14 | shahrud
# Processing Record 34 of Set 14 | dauphin
# Processing Record 35 of Set 14 | pechora
# Processing Record 36 of Set 14 | guia lopes da laguna
# Processing Record 37 of Set 14 | mezen
# Processing Record 38 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 39 of Set 14 | khani
# Processing Record 40 of Set 14 | karatuzskoye
# Processing Record 41 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 42 of Set 14 | peleduy
# Processing Record 43 of Set 14 | praya
# Processing Record 44 of Set 14 | tual
# Processing Record 45 of Set 14 | jasper
# Processing Record 46 of Set 14 | muros
# Processing Record 47 of Set 14 | langsa
# Processing Record 48 of Set 14 | dossor
# Processing Record 49 of Set 14 | ati
# Processing Record 50 of Set 14 | batangafo
# Processing Record 1 of Set 15 | mount pleasant
# Processing Record 2 of Set 15 | quatre cocos
# Processing Record 3 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 4 of Set 15 | macusani
# Processing Record 5 of Set 15 | morant bay
# Processing Record 6 of Set 15 | vildbjerg
# Processing Record 7 of Set 15 | barcelos
# Processing Record 8 of Set 15 | guicheng
# City not found. Skipping...
# Processing Record 9 of Set 15 | tuy hoa
# Processing Record 10 of Set 15 | teknaf
# Processing Record 11 of Set 15 | francisco beltrao
# Processing Record 12 of Set 15 | miri
# Processing Record 13 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 15 | xiongzhou
# Processing Record 15 of Set 15 | songjianghe
# Processing Record 16 of Set 15 | caxito
# Processing Record 17 of Set 15 | tula
# Processing Record 18 of Set 15 | bac giang
# Processing Record 19 of Set 15 | leticia
# Processing Record 20 of Set 15 | inirida
# Processing Record 21 of Set 15 | jizan
# Processing Record 22 of Set 15 | seoul
# Processing Record 23 of Set 15 | togul
# Processing Record 24 of Set 15 | mabaruma
# Processing Record 25 of Set 15 | kieta
# Processing Record 26 of Set 15 | sinfra
# Processing Record 27 of Set 15 | port blair
# Processing Record 28 of Set 15 | pointe michel
# Processing Record 29 of Set 15 | baykit
# Processing Record 30 of Set 15 | belmonte
# Processing Record 31 of Set 15 | kendrapara
# Processing Record 32 of Set 15 | adre
# Processing Record 33 of Set 15 | jiangkou
# Processing Record 34 of Set 15 | vestmanna
# Processing Record 35 of Set 15 | mecca
# Processing Record 36 of Set 15 | toppenish
# Processing Record 37 of Set 15 | skaudvile
# Processing Record 38 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 39 of Set 15 | palana
# Processing Record 40 of Set 15 | atasu
# Processing Record 41 of Set 15 | santiago del estero
# Processing Record 42 of Set 15 | dankov
# Processing Record 43 of Set 15 | fuengirola
# Processing Record 44 of Set 15 | pagudpud
# Processing Record 45 of Set 15 | hudson bay
# Processing Record 46 of Set 15 | pitimbu
# Processing Record 47 of Set 15 | moses lake
# Processing Record 48 of Set 15 | faanui
# Processing Record 49 of Set 15 | luwuk
# Processing Record 50 of Set 15 | caravelas
# Processing Record 1 of Set 16 | borgarnes
# Processing Record 2 of Set 16 | sataua
# City not found. Skipping...
# Processing Record 3 of Set 16 | konevo
# Processing Record 4 of Set 16 | berlevag
# Processing Record 5 of Set 16 | adra
# Processing Record 6 of Set 16 | uruzgan
# Processing Record 7 of Set 16 | asfi
# Processing Record 8 of Set 16 | chapais
# Processing Record 9 of Set 16 | kiruna
# Processing Record 10 of Set 16 | uyuni
# Processing Record 11 of Set 16 | nouadhibou
# Processing Record 12 of Set 16 | salalah
# Processing Record 13 of Set 16 | nyurba
# Processing Record 14 of Set 16 | mpongwe
# Processing Record 15 of Set 16 | vao
# Processing Record 16 of Set 16 | dzilam gonzalez
# Processing Record 17 of Set 16 | mirandela
# Processing Record 18 of Set 16 | alamogordo
# Processing Record 19 of Set 16 | namli
# Processing Record 20 of Set 16 | walvis bay
# Processing Record 21 of Set 16 | marzuq
# Processing Record 22 of Set 16 | ndende
# Processing Record 23 of Set 16 | hamilton
# Processing Record 24 of Set 16 | qidong
# Processing Record 25 of Set 16 | port keats
# Processing Record 26 of Set 16 | lugovoy
# Processing Record 27 of Set 16 | bahia de caraquez
# Processing Record 28 of Set 16 | lardos
# Processing Record 29 of Set 16 | yumbing
# Processing Record 30 of Set 16 | ahuimanu
# Processing Record 31 of Set 16 | puerto escondido
# Processing Record 32 of Set 16 | lisburn
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Bluff -46.6000  168.3333     53.80        76         100
# 1              Gat  31.6100   34.7642     50.40       100           9
# 2             Yuli   9.6989   10.2744     69.87        18          79
# 3            Vaini -21.2000 -175.2000     84.36        79          20
# 4             Ruwi  23.5996   58.5507     62.29        65           0
# 5          Neuquen -38.9516  -68.0591     87.69        40          20
# 6        Zarnovica  48.4812   18.7157     36.66        98          74
# 7  Arraial Do Cabo -22.9661  -42.0278     76.96        88           0
# 8        Carnarvon -24.8667  113.6333     77.07        73           0
# 9        Wadi Musa  30.3222   35.4793     34.63        81          33
#
#    Wind Speed Country Current Description                 Date
# 0       10.92      NZ     overcast clouds  2022-01-25 23:44:06
# 1       10.38      IL           clear sky  2022-01-25 23:44:07
# 2       10.38      NG       broken clouds  2022-01-25 23:44:07
# 3       10.36      TO          few clouds  2022-01-25 23:41:06
# 4        5.86      OM           clear sky  2022-01-25 23:44:07
# 5        9.22      AR          few clouds  2022-01-25 23:44:08
# 6        2.59      SK       broken clouds  2022-01-25 23:44:08
# 7       13.80      BR           clear sky  2022-01-25 23:43:48
# 8       13.80      AU          light rain  2022-01-25 23:44:09
# 9        6.17      JO    scattered clouds  2022-01-25 23:44:09

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/Weather_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18884/2136155075.py in <module>
#       2 output_data_file = "Weather_Database/Weather_database.csv"
#       3 # Export the City_Data into a CSV.
# ----> 4 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# ~\miniconda3\envs\PytonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# ~\miniconda3\envs\PytonData\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~\miniconda3\envs\PytonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     241             errors=self.errors,
#     242             compression=self.compression,
# --> 243             storage_options=self.storage_options,
#     244         ) as handles:
#     245
#
# ~\miniconda3\envs\PytonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/Weather_database.csv'
