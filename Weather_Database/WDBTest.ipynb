# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
import requests
import csv

from citipy import citipy
from config import weather_api_key
from datetime import datetime
from scipy.stats import linregress
import timeit

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Openweather API

# e54b389430ada7e562d27816cae2bdaa

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e54b389430ada7e562d27816cae2bdaa"
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e54b389430ada7e562d27816cae2bdaa

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e54b389430ada7e562d27816cae2bdaa&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descr = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_descr,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
    # WHERE IS CITIES DEFINED IN MODULE!!!!???
        # Cell 3
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | tuktoyaktuk
# Processing Record 3 of Set 1 | mar del plata
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | san quintin
# Processing Record 8 of Set 1 | okha
# Processing Record 9 of Set 1 | waipawa
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | kavieng
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | la ronge
# Processing Record 14 of Set 1 | boyolangu
# Processing Record 15 of Set 1 | malakal
# Processing Record 16 of Set 1 | rio cuarto
# Processing Record 17 of Set 1 | kapaa
# Processing Record 18 of Set 1 | dikson
# Processing Record 19 of Set 1 | henties bay
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | navelim
# Processing Record 22 of Set 1 | provideniya
# Processing Record 23 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 1 | barrow
# Processing Record 25 of Set 1 | tasiilaq
# Processing Record 26 of Set 1 | carnarvon
# Processing Record 27 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 1 | navahrudak
# Processing Record 29 of Set 1 | palora
# Processing Record 30 of Set 1 | chuy
# Processing Record 31 of Set 1 | arraial do cabo
# Processing Record 32 of Set 1 | vardo
# Processing Record 33 of Set 1 | ribeira grande
# Processing Record 34 of Set 1 | mao
# Processing Record 35 of Set 1 | qaanaaq
# Processing Record 36 of Set 1 | codajas
# Processing Record 37 of Set 1 | pevek
# Processing Record 38 of Set 1 | harrison
# Processing Record 39 of Set 1 | lompoc
# Processing Record 40 of Set 1 | leh
# Processing Record 41 of Set 1 | lebu
# Processing Record 42 of Set 1 | lindi
# Processing Record 43 of Set 1 | sunbury
# Processing Record 44 of Set 1 | mahebourg
# Processing Record 45 of Set 1 | vedaranniyam
# City not found. Skipping...
# Processing Record 46 of Set 1 | ardmore
# Processing Record 47 of Set 1 | kaitangata
# Processing Record 48 of Set 1 | englewood
# Processing Record 49 of Set 1 | new norfolk
# Processing Record 50 of Set 1 | osecina
# Processing Record 1 of Set 2 | buin
# Processing Record 2 of Set 2 | saint-philippe
# Processing Record 3 of Set 2 | nizwa
# Processing Record 4 of Set 2 | cooma
# Processing Record 5 of Set 2 | yellowknife
# Processing Record 6 of Set 2 | koygorodok
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | iqaluit
# Processing Record 9 of Set 2 | port elizabeth
# Processing Record 10 of Set 2 | sechura
# Processing Record 11 of Set 2 | jaffna
# Processing Record 12 of Set 2 | saint-georges
# Processing Record 13 of Set 2 | bom jesus do itabapoana
# Processing Record 14 of Set 2 | mataura
# Processing Record 15 of Set 2 | drezdenko
# Processing Record 16 of Set 2 | mackenzie
# Processing Record 17 of Set 2 | pedernales
# Processing Record 18 of Set 2 | parana
# Processing Record 19 of Set 2 | margate
# Processing Record 20 of Set 2 | nikolskoye
# Processing Record 21 of Set 2 | guerrero negro
# Processing Record 22 of Set 2 | cabo san lucas
# Processing Record 23 of Set 2 | truth or consequences
# Processing Record 24 of Set 2 | rikitea
# Processing Record 25 of Set 2 | sabratah
# Processing Record 26 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 2 | vestmannaeyjar
# Processing Record 28 of Set 2 | san patricio
# Processing Record 29 of Set 2 | bluff
# Processing Record 30 of Set 2 | port alfred
# Processing Record 31 of Set 2 | galveston
# Processing Record 32 of Set 2 | bengkulu
# Processing Record 33 of Set 2 | yako
# Processing Record 34 of Set 2 | sao joao da barra
# Processing Record 35 of Set 2 | atuona
# Processing Record 36 of Set 2 | hilo
# Processing Record 37 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 38 of Set 2 | half moon bay
# Processing Record 39 of Set 2 | airai
# Processing Record 40 of Set 2 | gunib
# Processing Record 41 of Set 2 | calbe
# Processing Record 42 of Set 2 | sao filipe
# Processing Record 43 of Set 2 | riyadh
# Processing Record 44 of Set 2 | porto novo
# Processing Record 45 of Set 2 | kushima
# Processing Record 46 of Set 2 | pisco
# Processing Record 47 of Set 2 | ambon
# Processing Record 48 of Set 2 | puerto ayora
# Processing Record 49 of Set 2 | kodiak
# Processing Record 50 of Set 2 | bad freienwalde
# Processing Record 1 of Set 3 | victoria
# Processing Record 2 of Set 3 | coquimbo
# Processing Record 3 of Set 3 | deputatskiy
# Processing Record 4 of Set 3 | mutsamudu
# City not found. Skipping...
# Processing Record 5 of Set 3 | port augusta
# Processing Record 6 of Set 3 | atherton
# Processing Record 7 of Set 3 | high level
# Processing Record 8 of Set 3 | nishihara
# Processing Record 9 of Set 3 | lagoa
# Processing Record 10 of Set 3 | manokwari
# Processing Record 11 of Set 3 | natitingou
# Processing Record 12 of Set 3 | murray bridge
# Processing Record 13 of Set 3 | nortelandia
# Processing Record 14 of Set 3 | coolum beach
# Processing Record 15 of Set 3 | palmer
# Processing Record 16 of Set 3 | albany
# Processing Record 17 of Set 3 | empalme
# Processing Record 18 of Set 3 | punta arenas
# Processing Record 19 of Set 3 | ilulissat
# Processing Record 20 of Set 3 | vestmanna
# Processing Record 21 of Set 3 | belaya gora
# Processing Record 22 of Set 3 | vila velha
# Processing Record 23 of Set 3 | eskasem
# City not found. Skipping...
# Processing Record 24 of Set 3 | salinopolis
# Processing Record 25 of Set 3 | florianopolis
# Processing Record 26 of Set 3 | puri
# Processing Record 27 of Set 3 | solwezi
# Processing Record 28 of Set 3 | surt
# Processing Record 29 of Set 3 | ono
# Processing Record 30 of Set 3 | itoman
# Processing Record 31 of Set 3 | harper
# Processing Record 32 of Set 3 | upernavik
# Processing Record 33 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 3 | coahuayana
# Processing Record 35 of Set 3 | laredo
# Processing Record 36 of Set 3 | doha
# Processing Record 37 of Set 3 | clyde river
# Processing Record 38 of Set 3 | kavaratti
# Processing Record 39 of Set 3 | zhangjiakou
# Processing Record 40 of Set 3 | kruisfontein
# Processing Record 41 of Set 3 | alofi
# Processing Record 42 of Set 3 | talnakh
# Processing Record 43 of Set 3 | berga
# Processing Record 44 of Set 3 | tarakan
# Processing Record 45 of Set 3 | aklavik
# Processing Record 46 of Set 3 | te anau
# Processing Record 47 of Set 3 | adrar
# Processing Record 48 of Set 3 | srandakan
# Processing Record 49 of Set 3 | yiyang
# Processing Record 50 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 4 | codrington
# Processing Record 2 of Set 4 | bambous virieux
# Processing Record 3 of Set 4 | bubaque
# Processing Record 4 of Set 4 | georgetown
# Processing Record 5 of Set 4 | wagar
# Processing Record 6 of Set 4 | narsaq
# Processing Record 7 of Set 4 | rocha
# Processing Record 8 of Set 4 | chokurdakh
# Processing Record 9 of Set 4 | usogorsk
# Processing Record 10 of Set 4 | katsuura
# Processing Record 11 of Set 4 | bonthe
# Processing Record 12 of Set 4 | nantucket
# Processing Record 13 of Set 4 | hovd
# Processing Record 14 of Set 4 | banda aceh
# Processing Record 15 of Set 4 | mirnyy
# Processing Record 16 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 4 | jamestown
# Processing Record 18 of Set 4 | salalah
# Processing Record 19 of Set 4 | esperance
# Processing Record 20 of Set 4 | khatanga
# Processing Record 21 of Set 4 | burriana
# Processing Record 22 of Set 4 | birao
# Processing Record 23 of Set 4 | thompson
# Processing Record 24 of Set 4 | foumban
# Processing Record 25 of Set 4 | paramonga
# Processing Record 26 of Set 4 | lovington
# Processing Record 27 of Set 4 | saint anthony
# Processing Record 28 of Set 4 | kuusamo
# Processing Record 29 of Set 4 | tallmadge
# Processing Record 30 of Set 4 | uruzgan
# Processing Record 31 of Set 4 | salym
# Processing Record 32 of Set 4 | dingle
# Processing Record 33 of Set 4 | skaelskor
# Processing Record 34 of Set 4 | shingu
# Processing Record 35 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 4 | masvingo
# Processing Record 37 of Set 4 | vao
# Processing Record 38 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 4 | tura
# Processing Record 40 of Set 4 | benghazi
# Processing Record 41 of Set 4 | northam
# Processing Record 42 of Set 4 | ukiah
# Processing Record 43 of Set 4 | butterworth
# Processing Record 44 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 4 | bac lieu
# Processing Record 46 of Set 4 | saldanha
# Processing Record 47 of Set 4 | padang
# Processing Record 48 of Set 4 | ovruch
# Processing Record 49 of Set 4 | kununurra
# Processing Record 50 of Set 4 | kahului
# Processing Record 1 of Set 5 | luderitz
# Processing Record 2 of Set 5 | port hedland
# Processing Record 3 of Set 5 | okandja
# City not found. Skipping...
# Processing Record 4 of Set 5 | noumea
# Processing Record 5 of Set 5 | namibe
# Processing Record 6 of Set 5 | igrim
# Processing Record 7 of Set 5 | frutal
# Processing Record 8 of Set 5 | eldikan
# City not found. Skipping...
# Processing Record 9 of Set 5 | dongtai
# Processing Record 10 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 5 | abu dhabi
# Processing Record 12 of Set 5 | oktyabrskiy
# Processing Record 13 of Set 5 | vanimo
# Processing Record 14 of Set 5 | les ponts-de-ce
# Processing Record 15 of Set 5 | okakarara
# Processing Record 16 of Set 5 | sao felix do xingu
# Processing Record 17 of Set 5 | gat
# Processing Record 18 of Set 5 | zaysan
# Processing Record 19 of Set 5 | butaritari
# Processing Record 20 of Set 5 | ostrovnoy
# Processing Record 21 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 22 of Set 5 | rosarito
# Processing Record 23 of Set 5 | kiunga
# Processing Record 24 of Set 5 | zdvinsk
# Processing Record 25 of Set 5 | umm kaddadah
# Processing Record 26 of Set 5 | san antonio
# Processing Record 27 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 5 | komsomolskiy
# Processing Record 29 of Set 5 | jawhar
# Processing Record 30 of Set 5 | san rafael
# Processing Record 31 of Set 5 | cherskiy
# Processing Record 32 of Set 5 | college
# Processing Record 33 of Set 5 | ihosy
# Processing Record 34 of Set 5 | flinders
# Processing Record 35 of Set 5 | ucluelet
# Processing Record 36 of Set 5 | sandakan
# Processing Record 37 of Set 5 | quatre cocos
# Processing Record 38 of Set 5 | kirakira
# Processing Record 39 of Set 5 | grindavik
# Processing Record 40 of Set 5 | wuwei
# Processing Record 41 of Set 5 | maloshuyka
# City not found. Skipping...
# Processing Record 42 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 43 of Set 5 | cockburn town
# Processing Record 44 of Set 5 | qeshm
# Processing Record 45 of Set 5 | zaltan
# Processing Record 46 of Set 5 | bodh gaya
# Processing Record 47 of Set 5 | zyryanka
# Processing Record 48 of Set 5 | mount gambier
# Processing Record 49 of Set 5 | geraldton
# Processing Record 50 of Set 5 | san cristobal
# Processing Record 1 of Set 6 | shelburne
# Processing Record 2 of Set 6 | ziarat
# Processing Record 3 of Set 6 | gainesville
# Processing Record 4 of Set 6 | vagur
# Processing Record 5 of Set 6 | gemena
# Processing Record 6 of Set 6 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 7 of Set 6 | saskylakh
# Processing Record 8 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 6 | najran
# Processing Record 10 of Set 6 | wawina
# Processing Record 11 of Set 6 | broome
# Processing Record 12 of Set 6 | nizhnevartovsk
# Processing Record 13 of Set 6 | general roca
# Processing Record 14 of Set 6 | lasa
# Processing Record 15 of Set 6 | san rafael abajo
# Processing Record 16 of Set 6 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 17 of Set 6 | lensk
# Processing Record 18 of Set 6 | cururupu
# Processing Record 19 of Set 6 | kardla
# Processing Record 20 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 21 of Set 6 | hithadhoo
# Processing Record 22 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 23 of Set 6 | ambilobe
# Processing Record 24 of Set 6 | alyangula
# Processing Record 25 of Set 6 | sitka
# Processing Record 26 of Set 6 | turukhansk
# Processing Record 27 of Set 6 | namatanai
# Processing Record 28 of Set 6 | port blair
# Processing Record 29 of Set 6 | byron bay
# Processing Record 30 of Set 6 | kiruna
# Processing Record 31 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 6 | tuatapere
# Processing Record 34 of Set 6 | kalmunai
# Processing Record 35 of Set 6 | flin flon
# Processing Record 36 of Set 6 | aktau
# Processing Record 37 of Set 6 | price
# Processing Record 38 of Set 6 | severo-kurilsk
# Processing Record 39 of Set 6 | linxia
# Processing Record 40 of Set 6 | cidreira
# Processing Record 41 of Set 6 | lavrentiya
# Processing Record 42 of Set 6 | praia da vitoria
# Processing Record 43 of Set 6 | shitanjing
# Processing Record 44 of Set 6 | lere
# Processing Record 45 of Set 6 | benito juarez
# Processing Record 46 of Set 6 | ahipara
# Processing Record 47 of Set 6 | vila do maio
# Processing Record 48 of Set 6 | brae
# Processing Record 49 of Set 6 | gornopravdinsk
# Processing Record 50 of Set 6 | oriximina
# Processing Record 1 of Set 7 | churapcha
# Processing Record 2 of Set 7 | liverpool
# Processing Record 3 of Set 7 | santa isabel
# Processing Record 4 of Set 7 | havre-saint-pierre
# Processing Record 5 of Set 7 | khipro
# Processing Record 6 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 7 | jumla
# Processing Record 8 of Set 7 | inverell
# Processing Record 9 of Set 7 | san jeronimo
# Processing Record 10 of Set 7 | digby
# Processing Record 11 of Set 7 | havoysund
# Processing Record 12 of Set 7 | auki
# Processing Record 13 of Set 7 | norman wells
# Processing Record 14 of Set 7 | ponta do sol
# Processing Record 15 of Set 7 | parfino
# Processing Record 16 of Set 7 | kandrian
# Processing Record 17 of Set 7 | gravdal
# Processing Record 18 of Set 7 | castro
# Processing Record 19 of Set 7 | abu jubayhah
# City not found. Skipping...
# Processing Record 20 of Set 7 | chifeng
# Processing Record 21 of Set 7 | subaytilah
# City not found. Skipping...
# Processing Record 22 of Set 7 | nemuro
# Processing Record 23 of Set 7 | uchaly
# Processing Record 24 of Set 7 | marawi
# Processing Record 25 of Set 7 | verkhnevilyuysk
# Processing Record 26 of Set 7 | bathsheba
# Processing Record 27 of Set 7 | kingston
# Processing Record 28 of Set 7 | khani
# Processing Record 29 of Set 7 | chiredzi
# Processing Record 30 of Set 7 | novyy urengoy
# Processing Record 31 of Set 7 | stokmarknes
# Processing Record 32 of Set 7 | zhuhai
# Processing Record 33 of Set 7 | constitucion
# Processing Record 34 of Set 7 | klaksvik
# Processing Record 35 of Set 7 | fare
# Processing Record 36 of Set 7 | aswan
# Processing Record 37 of Set 7 | mkushi
# Processing Record 38 of Set 7 | yar-sale
# Processing Record 39 of Set 7 | wewak
# Processing Record 40 of Set 7 | ostersund
# Processing Record 41 of Set 7 | ancud
# Processing Record 42 of Set 7 | sobolevo
# Processing Record 43 of Set 7 | qinhuangdao
# Processing Record 44 of Set 7 | dhidhdhoo
# Processing Record 45 of Set 7 | avarua
# Processing Record 46 of Set 7 | bethel
# Processing Record 47 of Set 7 | batagay
# Processing Record 48 of Set 7 | eureka
# Processing Record 49 of Set 7 | faanui
# Processing Record 50 of Set 7 | sayyan
# Processing Record 1 of Set 8 | benguela
# Processing Record 2 of Set 8 | izumo
# Processing Record 3 of Set 8 | phan thiet
# Processing Record 4 of Set 8 | buraydah
# Processing Record 5 of Set 8 | kiama
# Processing Record 6 of Set 8 | kizema
# Processing Record 7 of Set 8 | port macquarie
# Processing Record 8 of Set 8 | east london
# Processing Record 9 of Set 8 | khandyga
# Processing Record 10 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 8 | katima mulilo
# Processing Record 12 of Set 8 | batagay-alyta
# Processing Record 13 of Set 8 | nouadhibou
# Processing Record 14 of Set 8 | manggar
# Processing Record 15 of Set 8 | husavik
# Processing Record 16 of Set 8 | isangel
# Processing Record 17 of Set 8 | nelson bay
# Processing Record 18 of Set 8 | bontang
# Processing Record 19 of Set 8 | krasnoselkup
# Processing Record 20 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 8 | kenai
# Processing Record 22 of Set 8 | pancas
# Processing Record 23 of Set 8 | leningradskiy
# Processing Record 24 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 25 of Set 8 | necochea
# Processing Record 26 of Set 8 | alghero
# Processing Record 27 of Set 8 | rabo de peixe
# Processing Record 28 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 29 of Set 8 | muros
# Processing Record 30 of Set 8 | plettenberg bay
# Processing Record 31 of Set 8 | krasnyy chikoy
# Processing Record 32 of Set 8 | werder
# Processing Record 33 of Set 8 | araouane
# Processing Record 34 of Set 8 | kurilsk
# Processing Record 35 of Set 8 | belyy yar
# Processing Record 36 of Set 8 | bafq
# Processing Record 37 of Set 8 | kostomuksha
# Processing Record 38 of Set 8 | hukay
# Processing Record 39 of Set 8 | deyang
# Processing Record 40 of Set 8 | villa florida
# Processing Record 41 of Set 8 | koumac
# Processing Record 42 of Set 8 | bartlesville
# Processing Record 43 of Set 8 | merauke
# Processing Record 44 of Set 8 | davila
# Processing Record 45 of Set 8 | mareeba
# Processing Record 46 of Set 8 | richards bay
# Processing Record 47 of Set 8 | kudahuvadhoo
# Processing Record 48 of Set 8 | igarka
# Processing Record 49 of Set 8 | trelew
# Processing Record 50 of Set 8 | green river
# Processing Record 1 of Set 9 | kilindoni
# Processing Record 2 of Set 9 | vilhena
# Processing Record 3 of Set 9 | carndonagh
# Processing Record 4 of Set 9 | quesnel
# Processing Record 5 of Set 9 | comodoro rivadavia
# Processing Record 6 of Set 9 | aden
# Processing Record 7 of Set 9 | mayo
# Processing Record 8 of Set 9 | juneau
# Processing Record 9 of Set 9 | portland
# Processing Record 10 of Set 9 | arman
# Processing Record 11 of Set 9 | chegutu
# Processing Record 12 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 9 | sakakah
# Processing Record 14 of Set 9 | san-pedro
# Processing Record 15 of Set 9 | penzance
# Processing Record 16 of Set 9 | poretskoye
# Processing Record 17 of Set 9 | kawalu
# Processing Record 18 of Set 9 | hasaki
# Processing Record 19 of Set 9 | teya
# Processing Record 20 of Set 9 | haines junction
# Processing Record 21 of Set 9 | yirol
# City not found. Skipping...
# Processing Record 22 of Set 9 | ibirapitanga
# Processing Record 23 of Set 9 | malgrat de mar
# Processing Record 24 of Set 9 | yantal
# Processing Record 25 of Set 9 | krasnyy yar
# Processing Record 26 of Set 9 | saint-pierre
# Processing Record 27 of Set 9 | yerbogachen
# Processing Record 28 of Set 9 | acu
# Processing Record 29 of Set 9 | kashi
# Processing Record 30 of Set 9 | domodossola
# Processing Record 31 of Set 9 | swellendam
# Processing Record 32 of Set 9 | los llanos de aridane
# Processing Record 33 of Set 9 | natal
# Processing Record 34 of Set 9 | makakilo city
# Processing Record 35 of Set 9 | saurimo
# Processing Record 36 of Set 9 | meybod
# Processing Record 37 of Set 9 | chicama
# Processing Record 38 of Set 9 | normandin
# Processing Record 39 of Set 9 | aloleng
# Processing Record 40 of Set 9 | chapais
# Processing Record 41 of Set 9 | fruitville
# Processing Record 42 of Set 9 | general pico
# Processing Record 43 of Set 9 | basco
# Processing Record 44 of Set 9 | eyl
# Processing Record 45 of Set 9 | majene
# Processing Record 46 of Set 9 | tungkang
# City not found. Skipping...
# Processing Record 47 of Set 9 | pangnirtung
# Processing Record 48 of Set 9 | yashkino
# Processing Record 49 of Set 9 | bagasara
# City not found. Skipping...
# Processing Record 50 of Set 9 | tiksi
# Processing Record 1 of Set 10 | masindi
# Processing Record 2 of Set 10 | yuci
# Processing Record 3 of Set 10 | astakos
# Processing Record 4 of Set 10 | muriwai beach
# Processing Record 5 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 6 of Set 10 | taoudenni
# Processing Record 7 of Set 10 | edd
# Processing Record 8 of Set 10 | gonbad-e qabus
# Processing Record 9 of Set 10 | olafsvik
# Processing Record 10 of Set 10 | paamiut
# Processing Record 11 of Set 10 | salvador
# Processing Record 12 of Set 10 | vilyuysk
# Processing Record 13 of Set 10 | sisimiut
# Processing Record 14 of Set 10 | sibolga
# Processing Record 15 of Set 10 | amboasary
# Processing Record 16 of Set 10 | shimoda
# Processing Record 17 of Set 10 | pontes e lacerda
# Processing Record 18 of Set 10 | anloga
# Processing Record 19 of Set 10 | mukhen
# Processing Record 20 of Set 10 | tatawin
# Processing Record 21 of Set 10 | rjukan
# Processing Record 22 of Set 10 | moorhead
# Processing Record 23 of Set 10 | paita
# Processing Record 24 of Set 10 | beyneu
# Processing Record 25 of Set 10 | sri aman
# Processing Record 26 of Set 10 | los chiles
# Processing Record 27 of Set 10 | inhambane
# Processing Record 28 of Set 10 | sioux lookout
# Processing Record 29 of Set 10 | canico
# Processing Record 30 of Set 10 | lerwick
# Processing Record 31 of Set 10 | san francisco
# Processing Record 32 of Set 10 | chinchani
# Processing Record 33 of Set 10 | tinskoy
# Processing Record 34 of Set 10 | canals
# Processing Record 35 of Set 10 | banjar
# Processing Record 36 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 10 | hirado
# Processing Record 38 of Set 10 | paternion
# Processing Record 39 of Set 10 | mosquera
# Processing Record 40 of Set 10 | plast
# Processing Record 41 of Set 10 | tommot
# Processing Record 42 of Set 10 | aasiaat
# Processing Record 43 of Set 10 | cachira
# Processing Record 44 of Set 10 | oriental
# Processing Record 45 of Set 10 | buala
# Processing Record 46 of Set 10 | paicandu
# Processing Record 47 of Set 10 | nanortalik
# Processing Record 48 of Set 10 | dogondoutchi
# Processing Record 49 of Set 10 | westport
# Processing Record 50 of Set 10 | nioro
# Processing Record 1 of Set 11 | san vicente de canete
# Processing Record 2 of Set 11 | melville
# Processing Record 3 of Set 11 | klitos
# Processing Record 4 of Set 11 | tambopata
# Processing Record 5 of Set 11 | hami
# Processing Record 6 of Set 11 | ode
# Processing Record 7 of Set 11 | fortuna
# Processing Record 8 of Set 11 | mahbubnagar
# Processing Record 9 of Set 11 | rock sound
# Processing Record 10 of Set 11 | camacha
# Processing Record 11 of Set 11 | evensk
# Processing Record 12 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 11 | marrakesh
# Processing Record 14 of Set 11 | awjilah
# Processing Record 15 of Set 11 | letka
# Processing Record 16 of Set 11 | touros
# Processing Record 17 of Set 11 | srednekolymsk
# Processing Record 18 of Set 11 | turinsk
# Processing Record 19 of Set 11 | hobyo
# Processing Record 20 of Set 11 | verkhnyaya inta
# Processing Record 21 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 22 of Set 11 | salmas
# Processing Record 23 of Set 11 | usinsk
# Processing Record 24 of Set 11 | tessalit
# Processing Record 25 of Set 11 | avera
# Processing Record 26 of Set 11 | timmins
# Processing Record 27 of Set 11 | riviere-au-renard
# Processing Record 28 of Set 11 | rancho palos verdes
# Processing Record 29 of Set 11 | micheweni
# Processing Record 30 of Set 11 | mitsamiouli
# Processing Record 31 of Set 11 | smithers
# Processing Record 32 of Set 11 | hambantota
# Processing Record 33 of Set 11 | arlit
# Processing Record 34 of Set 11 | muroto
# Processing Record 35 of Set 11 | alcudia
# Processing Record 36 of Set 11 | aleksandrovka
# Processing Record 37 of Set 11 | fort nelson
# Processing Record 38 of Set 11 | abu zabad
# Processing Record 39 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 40 of Set 11 | oparino
# Processing Record 41 of Set 11 | prince albert
# Processing Record 42 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 11 | maykain
# City not found. Skipping...
# Processing Record 44 of Set 11 | neuquen
# Processing Record 45 of Set 11 | ciempozuelos
# Processing Record 46 of Set 11 | kostek
# Processing Record 47 of Set 11 | terney
# Processing Record 48 of Set 11 | bilibino
# Processing Record 49 of Set 11 | san vicente
# Processing Record 50 of Set 11 | dublin
# Processing Record 1 of Set 12 | mentok
# City not found. Skipping...
# Processing Record 2 of Set 12 | tomatlan
# Processing Record 3 of Set 12 | viedma
# Processing Record 4 of Set 12 | cairns
# Processing Record 5 of Set 12 | rostovka
# Processing Record 6 of Set 12 | torbay
# Processing Record 7 of Set 12 | ust-kuyga
# Processing Record 8 of Set 12 | manavadar
# Processing Record 9 of Set 12 | vila franca do campo
# Processing Record 10 of Set 12 | ginir
# Processing Record 11 of Set 12 | port hardy
# Processing Record 12 of Set 12 | mkokotoni
# Processing Record 13 of Set 12 | magadan
# Processing Record 14 of Set 12 | pucara
# Processing Record 15 of Set 12 | jalu
# Processing Record 16 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 17 of Set 12 | conceicao do araguaia
# Processing Record 18 of Set 12 | seymchan
# Processing Record 19 of Set 12 | upata
# Processing Record 20 of Set 12 | kirksville
# Processing Record 21 of Set 12 | mizan teferi
# Processing Record 22 of Set 12 | sevlievo
# Processing Record 23 of Set 12 | mahanoro
# Processing Record 24 of Set 12 | risor
# Processing Record 25 of Set 12 | samagaltay
# Processing Record 26 of Set 12 | huilong
# Processing Record 27 of Set 12 | basugaon
# Processing Record 28 of Set 12 | lyngseidet
# Processing Record 29 of Set 12 | rokycany
# Processing Record 30 of Set 12 | linqiong
# Processing Record 31 of Set 12 | betanzos
# Processing Record 32 of Set 12 | mehamn
# Processing Record 33 of Set 12 | manoel urbano
# Processing Record 34 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 35 of Set 12 | barabinsk
# Processing Record 36 of Set 12 | ironton
# Processing Record 37 of Set 12 | collie
# Processing Record 38 of Set 12 | hailakandi
# Processing Record 39 of Set 12 | tecoanapa
# Processing Record 40 of Set 12 | samsun
# Processing Record 41 of Set 12 | port lincoln
# Processing Record 42 of Set 12 | chuchkovo
# Processing Record 43 of Set 12 | empangeni
# Processing Record 44 of Set 12 | calabozo
# Processing Record 45 of Set 12 | onguday
# Processing Record 46 of Set 12 | katobu
# Processing Record 47 of Set 12 | pontianak
# Processing Record 48 of Set 12 | zachagansk
# City not found. Skipping...
# Processing Record 49 of Set 12 | pozo colorado
# Processing Record 50 of Set 12 | sinnamary
# Processing Record 1 of Set 13 | san carlos de bariloche
# Processing Record 2 of Set 13 | shache
# Processing Record 3 of Set 13 | saint george
# Processing Record 4 of Set 13 | korla
# Processing Record 5 of Set 13 | tubmanburg
# Processing Record 6 of Set 13 | simbach
# Processing Record 7 of Set 13 | north bend
# Processing Record 8 of Set 13 | pacific grove
# Processing Record 9 of Set 13 | yalta
# Processing Record 10 of Set 13 | shunyi
# Processing Record 11 of Set 13 | amnat charoen
# Processing Record 12 of Set 13 | puerto escondido
# Processing Record 13 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 14 of Set 13 | whitehorse
# Processing Record 15 of Set 13 | qaqortoq
# Processing Record 16 of Set 13 | arroyo
# Processing Record 17 of Set 13 | vostok
# Processing Record 18 of Set 13 | sorong
# Processing Record 19 of Set 13 | bridlington
# Processing Record 20 of Set 13 | atambua
# Processing Record 21 of Set 13 | tiznit
# Processing Record 22 of Set 13 | tanglad
# Processing Record 23 of Set 13 | asau
# Processing Record 24 of Set 13 | dombarovskiy
# Processing Record 25 of Set 13 | bayan
# Processing Record 26 of Set 13 | pacifica
# Processing Record 27 of Set 13 | suntar
# Processing Record 28 of Set 13 | amapa
# Processing Record 29 of Set 13 | alice springs
# Processing Record 30 of Set 13 | lorengau
# Processing Record 31 of Set 13 | tambacounda
# Processing Record 32 of Set 13 | xai-xai
# Processing Record 33 of Set 13 | porto velho
# Processing Record 34 of Set 13 | nacogdoches
# Processing Record 35 of Set 13 | groningen
# Processing Record 36 of Set 13 | antalaha
# Processing Record 37 of Set 13 | yarmouth
# Processing Record 38 of Set 13 | svetlyy
# Processing Record 39 of Set 13 | svetlogorsk
# Processing Record 40 of Set 13 | calvinia
# Processing Record 41 of Set 13 | lamu
# Processing Record 42 of Set 13 | carutapera
# Processing Record 43 of Set 13 | biltine
# Processing Record 44 of Set 13 | baranain
# Processing Record 45 of Set 13 | cayenne
# Processing Record 46 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 13 | ginda
# Processing Record 48 of Set 13 | mangai
# Processing Record 49 of Set 13 | stornoway
# Processing Record 50 of Set 13 | sungaipenuh
# Processing Record 1 of Set 14 | mercedes
# Processing Record 2 of Set 14 | pochutla
# Processing Record 3 of Set 14 | savannah bight
# Processing Record 4 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 5 of Set 14 | santa catarina de tepehuanes
# Processing Record 6 of Set 14 | hamilton
# Processing Record 7 of Set 14 | blackfoot
# Processing Record 8 of Set 14 | rudbar
# Processing Record 9 of Set 14 | sinaloa
# Processing Record 10 of Set 14 | tocopilla
# Processing Record 11 of Set 14 | xining
# Processing Record 12 of Set 14 | gualaceo
# Processing Record 13 of Set 14 | aksu
# Processing Record 14 of Set 14 | pangai
# Processing Record 15 of Set 14 | meulaboh
# Processing Record 16 of Set 14 | totness
# Processing Record 17 of Set 14 | el faiyum
# City not found. Skipping...
# Processing Record 18 of Set 14 | vicuna
# Processing Record 19 of Set 14 | ribas do rio pardo
# Processing Record 20 of Set 14 | cabo rojo
# Processing Record 21 of Set 14 | fremont
# Processing Record 22 of Set 14 | thaton
# Processing Record 23 of Set 14 | betong
# Processing Record 24 of Set 14 | ambovombe
# Processing Record 25 of Set 14 | leca da palmeira
# Processing Record 26 of Set 14 | hukuntsi
# Processing Record 27 of Set 14 | makurdi
# Processing Record 28 of Set 14 | makrana
# Processing Record 29 of Set 14 | vagay
# Processing Record 30 of Set 14 | zhangye
# Processing Record 31 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 32 of Set 14 | wa
# City not found. Skipping...
# Processing Record 33 of Set 14 | sao jose da coroa grande
# Processing Record 34 of Set 14 | muzhi
# Processing Record 35 of Set 14 | anda
# Processing Record 36 of Set 14 | ushtobe
# Processing Record 37 of Set 14 | turtas
# Processing Record 38 of Set 14 | napasar
# Processing Record 39 of Set 14 | acapulco
# Processing Record 40 of Set 14 | khilok
# Processing Record 41 of Set 14 | killybegs
# Processing Record 42 of Set 14 | wellington
# Processing Record 43 of Set 14 | gerash
# Processing Record 44 of Set 14 | christchurch
# Processing Record 45 of Set 14 | brokopondo
# Processing Record 46 of Set 14 | shenjiamen
# Processing Record 47 of Set 14 | key west
# Processing Record 48 of Set 14 | faya
# Processing Record 49 of Set 14 | sturgeon bay
# Processing Record 50 of Set 14 | leshan
# Processing Record 1 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 15 | ishinomaki
# Processing Record 3 of Set 15 | issa
# Processing Record 4 of Set 15 | svetlaya
# Processing Record 5 of Set 15 | kutum
# Processing Record 6 of Set 15 | laguna
# Processing Record 7 of Set 15 | abensberg
# Processing Record 8 of Set 15 | saint-francois
# Processing Record 9 of Set 15 | biloela
# Processing Record 10 of Set 15 | bilma
# Processing Record 11 of Set 15 | lebork
# Processing Record 12 of Set 15 | guapi
# Processing Record 13 of Set 15 | nicoya
# Processing Record 14 of Set 15 | omboue
# Processing Record 15 of Set 15 | bairiki
# Processing Record 16 of Set 15 | kawana waters
# City not found. Skipping...
# Processing Record 17 of Set 15 | santa cruz
# Processing Record 18 of Set 15 | bury saint edmunds
# City not found. Skipping...
# Processing Record 19 of Set 15 | ornskoldsvik
# Processing Record 20 of Set 15 | sheboygan
# Processing Record 21 of Set 15 | tiarei
# Processing Record 22 of Set 15 | canberra
# Processing Record 23 of Set 15 | pangody
# Processing Record 24 of Set 15 | pathein
# Processing Record 25 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 15 | huangnihe
# Processing Record 27 of Set 15 | santa luzia
# Processing Record 28 of Set 15 | zhanakorgan
# Processing Record 29 of Set 15 | antofagasta
# Processing Record 30 of Set 15 | leeuwarden
# Processing Record 31 of Set 15 | kinsale
# Processing Record 32 of Set 15 | oistins
# Processing Record 33 of Set 15 | partizanske
# Processing Record 34 of Set 15 | stolbishche
# Processing Record 35 of Set 15 | traralgon
# Processing Record 36 of Set 15 | lalas
# Processing Record 37 of Set 15 | urusha
# Processing Record 38 of Set 15 | axim
# Processing Record 39 of Set 15 | gamba
# Processing Record 40 of Set 15 | orsha
# Processing Record 41 of Set 15 | saint marys
# Processing Record 42 of Set 15 | puerto baquerizo moreno
# Processing Record 43 of Set 15 | ayan
# Processing Record 44 of Set 15 | nizhniy kuranakh
# Processing Record 45 of Set 15 | davidson
# Processing Record 46 of Set 15 | sivas
# Processing Record 47 of Set 15 | pauini
# Processing Record 48 of Set 15 | dunedin
# Processing Record 49 of Set 15 | seguela
# Processing Record 50 of Set 15 | san carlos
# Processing Record 1 of Set 16 | chanute
# Processing Record 2 of Set 16 | hermiston
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Cape Town -33.9258   18.4232     67.10        89          20
# 1    Tuktoyaktuk  69.4541 -133.0374     17.60        93         100
# 2  Mar Del Plata -38.0023  -57.5575     71.87        87           0
# 3         Hobart -42.8794  147.3294     73.02        83          75
# 4        Ushuaia -54.8000  -68.3000     42.46        87         100
# 5    San Quintin  30.4833 -115.9500     59.38        66           2
# 6           Okha  53.5739  142.9478     -0.72        92          37
# 7        Waipawa -41.4122  175.5153     69.46        59          98
# 8     Bredasdorp -34.5322   20.0403     68.29        83          93
# 9        Kavieng  -2.5744  150.7967     84.99        69          64
#
#    Wind Speed Country      Current Description                 Date
# 0       12.66      ZA               few clouds  2022-01-25 02:51:49
# 1       13.80      CA          overcast clouds  2022-01-25 02:54:42
# 2        5.01      AR                clear sky  2022-01-25 02:54:43
# 3       11.50      AU            broken clouds  2022-01-25 02:51:28
# 4       31.07      AR  heavy intensity drizzle  2022-01-25 02:52:35
# 5        5.99      MX                clear sky  2022-01-25 02:54:43
# 6       12.17      RU         scattered clouds  2022-01-25 02:54:43
# 7        5.99      NZ          overcast clouds  2022-01-25 02:54:44
# 8        4.61      ZA          overcast clouds  2022-01-25 02:53:44
# 9        6.35      PG            broken clouds  2022-01-25 02:54:44
